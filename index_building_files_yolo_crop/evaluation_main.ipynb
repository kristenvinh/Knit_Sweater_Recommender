# %%
# search_hnsw.py
import hnswlib
import pickle
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os
from feature_extraction import extract_features # Your existing function

# --- Configuration ---
index_file = 'sweater_hnsw_ResNet50.bin'
pattern_ids_file = 'pattern_ids.pkl'
feature_dim = 1024 # Should match the dimension used for building the index

def recommend_similar_images(query_image_path, hnsw_index, pattern_ids, num_recommendations=5):
    """
    Finds and displays the most similar images to a query image using an HNSWlib index.
    """
    print(f"--- Generating recommendations for {os.path.basename(query_image_path)} ---")
    
    # --- 1. Extract features from the query image ---
    _, query_vector = extract_features(query_image_path)
    if query_vector is None or not isinstance(query_vector, np.ndarray):
        print(f"Could not extract features from {query_image_path}")
        return

    # HNSWlib requires a 1D or 2D array, and it must be float32
    query_vector = np.array(query_vector).astype('float32')
    
    # --- 2. Search the HNSWlib index ---
    # The knn_query method returns labels and distances for the k nearest neighbors
    labels, distances = hnsw_index.knn_query(query_vector, k=num_recommendations)

    # The result is a 2D array, so we get the first (and only) row
    neighbor_indices = labels[0]
    
    print(f"Found neighbors with indices: {neighbor_indices}")
    
    # --- 3. Display the results ---
    plt.figure(figsize=(15, 5))

    # Display Query Image
    ax = plt.subplot(1, num_recommendations + 1, 1)
    query_img = Image.open(query_image_path)
    ax.imshow(query_img)
    ax.set_title("Query Image")
    ax.axis("off")

    # Display Recommended Images
    for i, idx in enumerate(neighbor_indices):
        recommended_pattern_id = pattern_ids[idx]
        
        # IMPORTANT: Update this path to how your images are stored.
        # This example assumes a structure like: data_directory/pattern_id/image.jpg
        rec_img_folder = os.path.join('/Volumes/Extreme Pro/ANN_photos', recommended_pattern_id)
        
        # Find the first image in the recommended pattern folder to display
        try:
            image_files = [f for f in os.listdir(rec_img_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
            if not image_files:
                print(f"Warning: No images found for pattern {recommended_pattern_id}.")
                continue
            first_image_file = image_files[0]
            rec_img_path = os.path.join(rec_img_folder, first_image_file)

            ax = plt.subplot(1, num_recommendations + 1, i + 2)
            rec_img = Image.open(rec_img_path)
            ax.imshow(rec_img)
            ax.set_title(f'Rec #{i+1}\n{recommended_pattern_id}')
            ax.axis('off')
        except (IOError, IndexError) as e:
            print(f"Warning: Could not load image for pattern {recommended_pattern_id}. Error: {e}")


    plt.tight_layout()
    plt.show()

# %%
import os
import pickle
import hnswlib
import numpy as np
import time

# --- Configuration ---
test_image_folder = 'Evaluation_Sweaters/pullovers'
valid_image_extensions = ('.jpg', '.jpeg', '.png')

num_recommendations = 10


# --- Load HNSWlib index and pattern IDs ---
try:
    print(f"Loading pattern IDs from {pattern_ids_file}...")
    with open(pattern_ids_file, 'rb') as f:
        pattern_ids = pickle.load(f)

    print(f"Loading HNSWlib index from {index_file}...")
    num_elements = len(pattern_ids)
    
    hnsw_index = hnswlib.Index(space='cosine', dim=feature_dim)
    hnsw_index.load_index(index_file, max_elements=num_elements)
    
    hnsw_index.set_ef(1000) 
    print(f"Index loaded successfully. Set efSearch = 1000")
        
except (IOError, RuntimeError) as e:
    print(f"Error loading files: {e}")
    print("Please ensure you have run your index-building script first.")
    exit()

# --- Lists to store results for averaging ---
all_query_times_ms = []
all_hits = [] # 1 for a hit, 0 for a miss

# --- Run Recommendation for all images in the folder ---
if not os.path.isdir(test_image_folder):
    print(f"Error: Test image folder not found at '{test_image_folder}'")
else:
    print(f"\n--- Starting batch recommendation for all images in {test_image_folder} ---")
    
    # Get a clean list of just the image files
    image_files_to_process = [
        f for f in sorted(os.listdir(test_image_folder)) 
        if f.lower().endswith(valid_image_extensions)
    ]
    total_images = len(image_files_to_process)
    
    if total_images == 0:
        print(f"No valid images found in {test_image_folder}")
        exit()

    for i, image_filename in enumerate(image_files_to_process):
        
        test_image_path = os.path.join(test_image_folder, image_filename)
        print(f"\n=============================================")
        print(f"Testing Image {i+1}/{total_images}: {image_filename}")
        print(f"=============================================")
        
        try:
            # --- Step 1: Get the correct pattern ID from the filename ---
            
            # Get the ID (e.g., "123456") from the filename (e.g., "123456.jpg")
            id_from_file = image_filename.split('.')[0] # <-- CHANGED
            
            # Format it to match the IDs in your pattern_ids list (e.g., "pattern_123456")
            correct_pattern_id = f"pattern_{id_from_file}" # <-- CHANGED
            
            print(f"  > Ground Truth ID: {correct_pattern_id}")

            # --- Step 2: Extract features for the query image ---
            img_path_out, query_vector = extract_features(test_image_path)
            
            if not isinstance(query_vector, np.ndarray):
                print(f"  > ERROR: Failed to extract features. Skipping.")
                print(f"  > Details: {query_vector}")
                continue 

            # --- Step 3: Run the query and time it ---
            start_time = time.perf_counter()
            labels, distances = hnsw_index.knn_query(query_vector, k=num_recommendations)
            end_time = time.perf_counter()
            
            query_time_ms = (end_time - start_time) * 1000 
            all_query_times_ms.append(query_time_ms)
            print(f"  > Query Time: {query_time_ms:.4f} ms")

            # --- Step 4: Check for a "hit" ---
            recommended_pattern_ids = [pattern_ids[i] for i in labels[0]]
            print(f"  > Recommendations: {recommended_pattern_ids}")
            
            # This check will now compare "pattern_123456" with the list
            if correct_pattern_id in recommended_pattern_ids:
                all_hits.append(1)
                print(f"  > RESULT: HIT! Correct ID '{correct_pattern_id}' was found.")
            else:
                all_hits.append(0)
                print(f"  > RESULT: MISS. Correct ID '{correct_pattern_id}' not found.")
                
        except Exception as e:
            print(f"ERROR: Could not process {image_filename}: {e}")

    # --- End of loop ---

    print("\n--- Batch recommendation complete. ---")

    # --- Calculate and print final averages ---
    if not all_hits:
        print("No images were processed successfully.")
    else:
        total_processed = len(all_hits)
        num_hits = np.sum(all_hits)
        avg_accuracy = (num_hits / total_processed) * 100
        avg_time = np.mean(all_query_times_ms)
        
        print("\n================== FINAL RESULTS ==================")
        print(f"Total Images Processed: {total_processed}")
        print(f"Total Hits (Recall@{num_recommendations}): {num_hits}")
        print(f"Average Accuracy (R@{num_recommendations}): {avg_accuracy:.2f}%")
        print(f"Average Query Time: {avg_time:.4f} ms")
        print("=================================================")
# Out:
# Loading pattern IDs from pattern_ids.pkl...
# Loading HNSWlib index from sweater_hnsw_ResNet50.bin...
# Index loaded successfully. Set efSearch = 1000
#
# --- Starting batch recommendation for all images in Evaluation_Sweaters/pullovers ---
#
# =============================================
# Testing Image 1/50: 1001132.jpeg
# =============================================
#   > Ground Truth ID: pattern_1001132
# Final crop size: width=318, height=480
# Original size: width=640, height=480
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1001132.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step
#   > Query Time: 6.6479 ms
#   > Recommendations: ['pattern_439806', 'pattern_531287', 'pattern_7375130', 'pattern_1080171', 'pattern_11562', 'pattern_573606', 'pattern_1277300', 'pattern_7376646', 'pattern_1021796', 'pattern_564348']
#   > RESULT: MISS. Correct ID 'pattern_1001132' not found.
#
# =============================================
# Testing Image 2/50: 100437.jpeg
# =============================================
#   > Ground Truth ID: pattern_100437
# Final crop size: width=303, height=592
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/100437.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 4.6900 ms
#   > Recommendations: ['pattern_804039', 'pattern_106122', 'pattern_489', 'pattern_1212645', 'pattern_106068', 'pattern_1059845', 'pattern_954008', 'pattern_980555', 'pattern_510936', 'pattern_780598']
#   > RESULT: MISS. Correct ID 'pattern_100437' not found.
#
# =============================================
# Testing Image 3/50: 1021796.jpeg
# =============================================
#   > Ground Truth ID: pattern_1021796
#   -> Pose failed. Fallback crop (Segment) for Evaluation_Sweaters/pullovers/1021796.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.6934 ms
#   > Recommendations: ['pattern_878969', 'pattern_27666', 'pattern_990127', 'pattern_356532', 'pattern_769231', 'pattern_583745', 'pattern_7363890', 'pattern_478226', 'pattern_159645', 'pattern_1080573']
#   > RESULT: MISS. Correct ID 'pattern_1021796' not found.
#
# =============================================
# Testing Image 4/50: 1037791.jpeg
# =============================================
#   > Ground Truth ID: pattern_1037791
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.7154 ms
#   > Recommendations: ['pattern_7349096', 'pattern_7373408', 'pattern_1268560', 'pattern_918521', 'pattern_1161493', 'pattern_833778', 'pattern_822497', 'pattern_7380686', 'pattern_1131558', 'pattern_1149619']
#   > RESULT: MISS. Correct ID 'pattern_1037791' not found.
#
# =============================================
# Testing Image 5/50: 1066129.jpeg
# =============================================
#   > Ground Truth ID: pattern_1066129
# Final crop size: width=434, height=596
# Original size: width=595, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1066129.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 5.0310 ms
#   > Recommendations: ['pattern_883608', 'pattern_467657', 'pattern_1072713', 'pattern_123918', 'pattern_7286483', 'pattern_1105725', 'pattern_1277075', 'pattern_347397', 'pattern_1069107', 'pattern_7404112']
#   > RESULT: MISS. Correct ID 'pattern_1066129' not found.
#
# =============================================
# Testing Image 6/50: 1094188.png
# =============================================
#   > Ground Truth ID: pattern_1094188
# Final crop size: width=142, height=248
# Original size: width=296, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1094188.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.9514 ms
#   > Recommendations: ['pattern_1359459', 'pattern_482269', 'pattern_978951', 'pattern_482573', 'pattern_1183899', 'pattern_746928', 'pattern_1307528', 'pattern_1216697', 'pattern_648406', 'pattern_1204473']
#   > RESULT: MISS. Correct ID 'pattern_1094188' not found.
#
# =============================================
# Testing Image 7/50: 1105965.jpeg
# =============================================
#   > Ground Truth ID: pattern_1105965
# Final crop size: width=198, height=345
# Original size: width=356, height=500
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1105965.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 4.7735 ms
#   > Recommendations: ['pattern_1086012', 'pattern_885060', 'pattern_632501', 'pattern_13692', 'pattern_7324048', 'pattern_1261294', 'pattern_112345', 'pattern_720284', 'pattern_923031', 'pattern_1238361']
#   > RESULT: MISS. Correct ID 'pattern_1105965' not found.
#
# =============================================
# Testing Image 8/50: 1115643.jpeg
# =============================================
#   > Ground Truth ID: pattern_1115643
# Final crop size: width=246, height=338
# Original size: width=592, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1115643.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 5.2221 ms
#   > Recommendations: ['pattern_1065865', 'pattern_1354290', 'pattern_1051939', 'pattern_1312324', 'pattern_1167473', 'pattern_7357117', 'pattern_1302699', 'pattern_1188308', 'pattern_1002910', 'pattern_7390875']
#   > RESULT: MISS. Correct ID 'pattern_1115643' not found.
#
# =============================================
# Testing Image 9/50: 1118466.jpeg
# =============================================
#   > Ground Truth ID: pattern_1118466
# Final crop size: width=304, height=416
# Original size: width=539, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1118466.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 5.0809 ms
#   > Recommendations: ['pattern_728386', 'pattern_1022709', 'pattern_1323159', 'pattern_1034309', 'pattern_1357964', 'pattern_1059845', 'pattern_547608', 'pattern_1155036', 'pattern_980654', 'pattern_7415052']
#   > RESULT: MISS. Correct ID 'pattern_1118466' not found.
#
# =============================================
# Testing Image 10/50: 1138136.jpeg
# =============================================
#   > Ground Truth ID: pattern_1138136
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 5.2847 ms
#   > Recommendations: ['pattern_7316176', 'pattern_552612', 'pattern_104569', 'pattern_7311540', 'pattern_1369867', 'pattern_1129633', 'pattern_7378104', 'pattern_1132748', 'pattern_1169993', 'pattern_918521']
#   > RESULT: MISS. Correct ID 'pattern_1138136' not found.
#
# =============================================
# Testing Image 11/50: 1175440.jpg
# =============================================
#   > Ground Truth ID: pattern_1175440
# Final crop size: width=325, height=555
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1175440.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 5.0652 ms
#   > Recommendations: ['pattern_1328930', 'pattern_1189018', 'pattern_839122', 'pattern_1132748', 'pattern_1308526', 'pattern_1169527', 'pattern_7415696', 'pattern_510648', 'pattern_1243136', 'pattern_1279061']
#   > RESULT: MISS. Correct ID 'pattern_1175440' not found.
#
# =============================================
# Testing Image 12/50: 1242444.jpeg
# =============================================
#   > Ground Truth ID: pattern_1242444
# Final crop size: width=247, height=402
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1242444.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 4.8612 ms
#   > Recommendations: ['pattern_262', 'pattern_1008560', 'pattern_7292969', 'pattern_256386', 'pattern_4571', 'pattern_1246392', 'pattern_513640', 'pattern_244091', 'pattern_150670', 'pattern_262357']
#   > RESULT: MISS. Correct ID 'pattern_1242444' not found.
#
# =============================================
# Testing Image 13/50: 1245286.jpeg
# =============================================
#   > Ground Truth ID: pattern_1245286
# Final crop size: width=184, height=344
# Original size: width=426, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1245286.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 4.4753 ms
#   > Recommendations: ['pattern_426137', 'pattern_393373', 'pattern_744418', 'pattern_1296467', 'pattern_21030', 'pattern_604509', 'pattern_679052', 'pattern_1197877', 'pattern_4064', 'pattern_66223']
#   > RESULT: MISS. Correct ID 'pattern_1245286' not found.
#
# =============================================
# Testing Image 14/50: 1261520.jpeg
# =============================================
#   > Ground Truth ID: pattern_1261520
# Final crop size: width=316, height=427
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1261520.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.6948 ms
#   > Recommendations: ['pattern_169400', 'pattern_1171694', 'pattern_432310', 'pattern_418763', 'pattern_133', 'pattern_834455', 'pattern_7342548', 'pattern_1005228', 'pattern_962103', 'pattern_884822']
#   > RESULT: MISS. Correct ID 'pattern_1261520' not found.
#
# =============================================
# Testing Image 15/50: 1269391.jpeg
# =============================================
#   > Ground Truth ID: pattern_1269391
# Final crop size: width=338, height=532
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1269391.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 4.7620 ms
#   > Recommendations: ['pattern_1277075', 'pattern_675518', 'pattern_7415052', 'pattern_763850', 'pattern_7289251', 'pattern_1275703', 'pattern_1062214', 'pattern_690062', 'pattern_913969', 'pattern_1138101']
#   > RESULT: MISS. Correct ID 'pattern_1269391' not found.
#
# =============================================
# Testing Image 16/50: 1269666.jpeg
# =============================================
#   > Ground Truth ID: pattern_1269666
# Final crop size: width=235, height=381
# Original size: width=427, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1269666.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.9406 ms
#   > Recommendations: ['pattern_1118494', 'pattern_1350513', 'pattern_1064399', 'pattern_865524', 'pattern_1232298', 'pattern_4684', 'pattern_7299184', 'pattern_898377', 'pattern_7364976', 'pattern_1092278']
#   > RESULT: MISS. Correct ID 'pattern_1269666' not found.
#
# =============================================
# Testing Image 17/50: 1273349.jpeg
# =============================================
#   > Ground Truth ID: pattern_1273349
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 5.3544 ms
#   > Recommendations: ['pattern_951587', 'pattern_7282372', 'pattern_7338556', 'pattern_1125895', 'pattern_1273349', 'pattern_1260158', 'pattern_671234', 'pattern_827365', 'pattern_7388037', 'pattern_7306632']
#   > RESULT: HIT! Correct ID 'pattern_1273349' was found.
#
# =============================================
# Testing Image 18/50: 1277038.jpeg
# =============================================
#   > Ground Truth ID: pattern_1277038
# Final crop size: width=185, height=295
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1277038.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 4.3886 ms
#   > Recommendations: ['pattern_1044574', 'pattern_1102968', 'pattern_1077466', 'pattern_864731', 'pattern_867902', 'pattern_1235299', 'pattern_386850', 'pattern_23753', 'pattern_21924', 'pattern_601574']
#   > RESULT: MISS. Correct ID 'pattern_1277038' not found.
#
# =============================================
# Testing Image 19/50: 1309104.jpeg
# =============================================
#   > Ground Truth ID: pattern_1309104
# Final crop size: width=226, height=367
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1309104.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#   > Query Time: 4.8299 ms
#   > Recommendations: ['pattern_7394566', 'pattern_686627', 'pattern_607819', 'pattern_537939', 'pattern_135', 'pattern_7370441', 'pattern_879419', 'pattern_1021432', 'pattern_126498', 'pattern_320698']
#   > RESULT: MISS. Correct ID 'pattern_1309104' not found.
#
# =============================================
# Testing Image 20/50: 1314562.jpeg
# =============================================
#   > Ground Truth ID: pattern_1314562
# Final crop size: width=365, height=407
# Original size: width=640, height=427
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1314562.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.4016 ms
#   > Recommendations: ['pattern_615364', 'pattern_7401795', 'pattern_1306269', 'pattern_721536', 'pattern_1279444', 'pattern_435947', 'pattern_7450443', 'pattern_526861', 'pattern_479886', 'pattern_7345961']
#   > RESULT: MISS. Correct ID 'pattern_1314562' not found.
#
# =============================================
# Testing Image 21/50: 1318255.jpeg
# =============================================
#   > Ground Truth ID: pattern_1318255
# Final crop size: width=136, height=211
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1318255.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.7424 ms
#   > Recommendations: ['pattern_1318255', 'pattern_1174837', 'pattern_492958', 'pattern_661793', 'pattern_541317', 'pattern_417009', 'pattern_504541', 'pattern_1167847', 'pattern_586595', 'pattern_246857']
#   > RESULT: HIT! Correct ID 'pattern_1318255' was found.
#
# =============================================
# Testing Image 22/50: 1321524.jpeg
# =============================================
#   > Ground Truth ID: pattern_1321524
# Final crop size: width=228, height=311
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1321524.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#   > Query Time: 4.3785 ms
#   > Recommendations: ['pattern_1308742', 'pattern_7406196', 'pattern_1293794', 'pattern_1321524', 'pattern_7335505', 'pattern_1182021', 'pattern_250405', 'pattern_10116', 'pattern_7457930', 'pattern_327352']
#   > RESULT: HIT! Correct ID 'pattern_1321524' was found.
#
# =============================================
# Testing Image 23/50: 13854.jpeg
# =============================================
#   > Ground Truth ID: pattern_13854
# Final crop size: width=309, height=490
# Original size: width=481, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/13854.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.3340 ms
#   > Recommendations: ['pattern_236582', 'pattern_526583', 'pattern_1080573', 'pattern_277852', 'pattern_416645', 'pattern_1367876', 'pattern_507431', 'pattern_7328824', 'pattern_499761', 'pattern_119747']
#   > RESULT: MISS. Correct ID 'pattern_13854' not found.
#
# =============================================
# Testing Image 24/50: 141029.jpeg
# =============================================
#   > Ground Truth ID: pattern_141029
# Final crop size: width=133, height=204
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/141029.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 5.0509 ms
#   > Recommendations: ['pattern_1310361', 'pattern_7418682', 'pattern_1053816', 'pattern_875368', 'pattern_745191', 'pattern_949200', 'pattern_1307877', 'pattern_340722', 'pattern_940059', 'pattern_1006627']
#   > RESULT: MISS. Correct ID 'pattern_141029' not found.
#
# =============================================
# Testing Image 25/50: 276617.jpg
# =============================================
#   > Ground Truth ID: pattern_276617
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.4050 ms
#   > Recommendations: ['pattern_1320407', 'pattern_1327', 'pattern_1006197', 'pattern_1242444', 'pattern_83778', 'pattern_28172', 'pattern_1319779', 'pattern_864845', 'pattern_993794', 'pattern_1340154']
#   > RESULT: MISS. Correct ID 'pattern_276617' not found.
#
# =============================================
# Testing Image 26/50: 303674.jpeg
# =============================================
#   > Ground Truth ID: pattern_303674
# Final crop size: width=319, height=437
# Original size: width=640, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/303674.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 5.1617 ms
#   > Recommendations: ['pattern_903471', 'pattern_7342719', 'pattern_892', 'pattern_837488', 'pattern_427616', 'pattern_1318255', 'pattern_492958', 'pattern_1174837', 'pattern_81100', 'pattern_1192350']
#   > RESULT: MISS. Correct ID 'pattern_303674' not found.
#
# =============================================
# Testing Image 27/50: 363242.jpeg
# =============================================
#   > Ground Truth ID: pattern_363242
# Final crop size: width=357, height=519
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/363242.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.9752 ms
#   > Recommendations: ['pattern_1084877', 'pattern_1000790', 'pattern_55483', 'pattern_215760', 'pattern_1328963', 'pattern_1158986', 'pattern_323316', 'pattern_1319383', 'pattern_855203', 'pattern_458']
#   > RESULT: MISS. Correct ID 'pattern_363242' not found.
#
# =============================================
# Testing Image 28/50: 381119.jpeg
# =============================================
#   > Ground Truth ID: pattern_381119
# Final crop size: width=224, height=331
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/381119.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 5.3958 ms
#   > Recommendations: ['pattern_1110944', 'pattern_1014524', 'pattern_839122', 'pattern_7358177', 'pattern_1189018', 'pattern_814238', 'pattern_571711', 'pattern_1292756', 'pattern_969683', 'pattern_883608']
#   > RESULT: MISS. Correct ID 'pattern_381119' not found.
#
# =============================================
# Testing Image 29/50: 446142.jpeg
# =============================================
#   > Ground Truth ID: pattern_446142
#   -> Pose failed. Fallback crop (Segment) for Evaluation_Sweaters/pullovers/446142.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#   > Query Time: 4.5162 ms
#   > Recommendations: ['pattern_526308', 'pattern_913721', 'pattern_256842', 'pattern_4247', 'pattern_1074101', 'pattern_88371', 'pattern_17292', 'pattern_7874', 'pattern_97286', 'pattern_21792']
#   > RESULT: MISS. Correct ID 'pattern_446142' not found.
#
# =============================================
# Testing Image 30/50: 473885.jpeg
# =============================================
#   > Ground Truth ID: pattern_473885
# Final crop size: width=196, height=392
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/473885.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.8710 ms
#   > Recommendations: ['pattern_130491', 'pattern_875083', 'pattern_852796', 'pattern_199995', 'pattern_913721', 'pattern_424916', 'pattern_379678', 'pattern_537455', 'pattern_51014', 'pattern_221628']
#   > RESULT: MISS. Correct ID 'pattern_473885' not found.
#
# =============================================
# Testing Image 31/50: 491132.jpeg
# =============================================
#   > Ground Truth ID: pattern_491132
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 5.2044 ms
#   > Recommendations: ['pattern_754', 'pattern_820634', 'pattern_912900', 'pattern_19245', 'pattern_7329570', 'pattern_9621', 'pattern_88193', 'pattern_993794', 'pattern_1129633', 'pattern_942844']
#   > RESULT: MISS. Correct ID 'pattern_491132' not found.
#
# =============================================
# Testing Image 32/50: 543344.jpg
# =============================================
#   > Ground Truth ID: pattern_543344
# Final crop size: width=338, height=374
# Original size: width=640, height=521
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/543344.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#   > Query Time: 5.4994 ms
#   > Recommendations: ['pattern_1080890', 'pattern_7284139', 'pattern_1232620', 'pattern_1243773', 'pattern_54259', 'pattern_975899', 'pattern_826313', 'pattern_613913', 'pattern_1172285', 'pattern_1169993']
#   > RESULT: MISS. Correct ID 'pattern_543344' not found.
#
# =============================================
# Testing Image 33/50: 585377.jpg
# =============================================
#   > Ground Truth ID: pattern_585377
# Final crop size: width=311, height=408
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/585377.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
#   > Query Time: 5.1729 ms
#   > Recommendations: ['pattern_1178287', 'pattern_363242', 'pattern_761128', 'pattern_1140505', 'pattern_1004205', 'pattern_755525', 'pattern_781464', 'pattern_1024686', 'pattern_7431667', 'pattern_166076']
#   > RESULT: MISS. Correct ID 'pattern_585377' not found.
#
# =============================================
# Testing Image 34/50: 5870.jpeg
# =============================================
#   > Ground Truth ID: pattern_5870
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 4.9498 ms
#   > Recommendations: ['pattern_7315140', 'pattern_583745', 'pattern_1460', 'pattern_1367876', 'pattern_7323343', 'pattern_1071562', 'pattern_1080573', 'pattern_7326364', 'pattern_718850', 'pattern_5870']
#   > RESULT: HIT! Correct ID 'pattern_5870' was found.
#
# =============================================
# Testing Image 35/50: 639347.jpeg
# =============================================
#   > Ground Truth ID: pattern_639347
# Final crop size: width=214, height=332
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/639347.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 5.2259 ms
#   > Recommendations: ['pattern_466331', 'pattern_1085250', 'pattern_404213', 'pattern_1176350', 'pattern_1230595', 'pattern_1270436', 'pattern_653922', 'pattern_337716', 'pattern_1139994', 'pattern_1357260']
#   > RESULT: MISS. Correct ID 'pattern_639347' not found.
#
# =============================================
# Testing Image 36/50: 663573.jpeg
# =============================================
#   > Ground Truth ID: pattern_663573
# Final crop size: width=176, height=317
# Original size: width=603, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/663573.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 5.1785 ms
#   > Recommendations: ['pattern_111729', 'pattern_785011', 'pattern_1014060', 'pattern_1319383', 'pattern_430646', 'pattern_756303', 'pattern_1000790', 'pattern_832732', 'pattern_1129874', 'pattern_810352']
#   > RESULT: MISS. Correct ID 'pattern_663573' not found.
#
# =============================================
# Testing Image 37/50: 7296687.jpeg
# =============================================
#   > Ground Truth ID: pattern_7296687
# Final crop size: width=438, height=620
# Original size: width=486, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/7296687.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 5.4245 ms
#   > Recommendations: ['pattern_1323159', 'pattern_7296687', 'pattern_1101761', 'pattern_457171', 'pattern_1314893', 'pattern_761128', 'pattern_184', 'pattern_1130007', 'pattern_7416906', 'pattern_728386']
#   > RESULT: HIT! Correct ID 'pattern_7296687' was found.
#
# =============================================
# Testing Image 38/50: 7303862.jpeg
# =============================================
#   > Ground Truth ID: pattern_7303862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 5.2122 ms
#   > Recommendations: ['pattern_418763', 'pattern_94530', 'pattern_1134501', 'pattern_14754', 'pattern_1278864', 'pattern_97286', 'pattern_811803', 'pattern_483156', 'pattern_313490', 'pattern_1031867']
#   > RESULT: MISS. Correct ID 'pattern_7303862' not found.
#
# =============================================
# Testing Image 39/50: 7311058.jpg
# =============================================
#   > Ground Truth ID: pattern_7311058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 4.7498 ms
#   > Recommendations: ['pattern_122410', 'pattern_1227867', 'pattern_1131882', 'pattern_803050', 'pattern_7452453', 'pattern_1209887', 'pattern_1199216', 'pattern_534110', 'pattern_332466', 'pattern_335395']
#   > RESULT: MISS. Correct ID 'pattern_7311058' not found.
#
# =============================================
# Testing Image 40/50: 7313250.jpeg
# =============================================
#   > Ground Truth ID: pattern_7313250
# Final crop size: width=351, height=513
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/7313250.jpeg
#   -> Result was 100.0% black. Falling back to original image.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 5.2057 ms
#   > Recommendations: ['pattern_7415405', 'pattern_7368013', 'pattern_7390056', 'pattern_7342548', 'pattern_1068017', 'pattern_1019395', 'pattern_1021796', 'pattern_913969', 'pattern_803926', 'pattern_967318']
#   > RESULT: MISS. Correct ID 'pattern_7313250' not found.
#
# =============================================
# Testing Image 41/50: 7384360.jpg
# =============================================
#   > Ground Truth ID: pattern_7384360
# Final crop size: width=276, height=352
# Original size: width=640, height=480
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/7384360.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#   > Query Time: 5.8175 ms
#   > Recommendations: ['pattern_1342787', 'pattern_1350513', 'pattern_7364976', 'pattern_1232298', 'pattern_1267764', 'pattern_1158986', 'pattern_896264', 'pattern_854924', 'pattern_1354387', 'pattern_892']
#   > RESULT: MISS. Correct ID 'pattern_7384360' not found.
#
# =============================================
# Testing Image 42/50: 817885.jpeg
# =============================================
#   > Ground Truth ID: pattern_817885
# Final crop size: width=338, height=606
# Original size: width=526, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/817885.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 4.6862 ms
#   > Recommendations: ['pattern_844844', 'pattern_77366', 'pattern_1070475', 'pattern_13692', 'pattern_720284', 'pattern_29595', 'pattern_1021796', 'pattern_923031', 'pattern_439806', 'pattern_1138339']
#   > RESULT: MISS. Correct ID 'pattern_817885' not found.
#
# =============================================
# Testing Image 43/50: 817988.jpeg
# =============================================
#   > Ground Truth ID: pattern_817988
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.8798 ms
#   > Recommendations: ['pattern_1340154', 'pattern_864845', 'pattern_1215907', 'pattern_993794', 'pattern_1129633', 'pattern_1185088', 'pattern_7289213', 'pattern_46846', 'pattern_1242444', 'pattern_1006197']
#   > RESULT: MISS. Correct ID 'pattern_817988' not found.
#
# =============================================
# Testing Image 44/50: 858135.jpeg
# =============================================
#   > Ground Truth ID: pattern_858135
# Final crop size: width=360, height=525
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/858135.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 5.0502 ms
#   > Recommendations: ['pattern_1138101', 'pattern_972398', 'pattern_7378104', 'pattern_1207734', 'pattern_1341627', 'pattern_1110661', 'pattern_1092050', 'pattern_1314844', 'pattern_950451', 'pattern_814238']
#   > RESULT: MISS. Correct ID 'pattern_858135' not found.
#
# =============================================
# Testing Image 45/50: 871033.jpeg
# =============================================
#   > Ground Truth ID: pattern_871033
# Final crop size: width=256, height=381
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/871033.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 5.0005 ms
#   > Recommendations: ['pattern_1126466', 'pattern_104569', 'pattern_639901', 'pattern_202689', 'pattern_182719', 'pattern_871033', 'pattern_273472', 'pattern_679040', 'pattern_1110944', 'pattern_877888']
#   > RESULT: HIT! Correct ID 'pattern_871033' was found.
#
# =============================================
# Testing Image 46/50: 873566.jpg
# =============================================
#   > Ground Truth ID: pattern_873566
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 4.8642 ms
#   > Recommendations: ['pattern_873566', 'pattern_1180265', 'pattern_1092110', 'pattern_1172185', 'pattern_1234982', 'pattern_9155', 'pattern_7282372', 'pattern_1217824', 'pattern_273815', 'pattern_7402423']
#   > RESULT: HIT! Correct ID 'pattern_873566' was found.
#
# =============================================
# Testing Image 47/50: 873567.jpg
# =============================================
#   > Ground Truth ID: pattern_873567
# Final crop size: width=133, height=226
# Original size: width=287, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/873567.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.5738 ms
#   > Recommendations: ['pattern_319269', 'pattern_94848', 'pattern_925323', 'pattern_7323343', 'pattern_969683', 'pattern_596471', 'pattern_7304623', 'pattern_7459904', 'pattern_855555', 'pattern_1080171']
#   > RESULT: MISS. Correct ID 'pattern_873567' not found.
#
# =============================================
# Testing Image 48/50: 901966.jpg
# =============================================
#   > Ground Truth ID: pattern_901966
#   -> Pose failed. Fallback crop (Segment) for Evaluation_Sweaters/pullovers/901966.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.4873 ms
#   > Recommendations: ['pattern_7427302', 'pattern_7465247', 'pattern_831203', 'pattern_989024', 'pattern_1150968', 'pattern_744422', 'pattern_7287874', 'pattern_667880', 'pattern_966254', 'pattern_29883']
#   > RESULT: MISS. Correct ID 'pattern_901966' not found.
#
# =============================================
# Testing Image 49/50: 971112.jpeg
# =============================================
#   > Ground Truth ID: pattern_971112
# Final crop size: width=417, height=585
# Original size: width=640, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/971112.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.9428 ms
#   > Recommendations: ['pattern_1106464', 'pattern_1071483', 'pattern_7390056', 'pattern_247632', 'pattern_1340360', 'pattern_971112', 'pattern_788760', 'pattern_1051939', 'pattern_1136335', 'pattern_7375130']
#   > RESULT: HIT! Correct ID 'pattern_971112' was found.
#
# =============================================
# Testing Image 50/50: 998032.jpeg
# =============================================
#   > Ground Truth ID: pattern_998032
# Final crop size: width=220, height=410
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/998032.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.9258 ms
#   > Recommendations: ['pattern_543197', 'pattern_692236', 'pattern_1291013', 'pattern_1226977', 'pattern_416755', 'pattern_506600', 'pattern_399719', 'pattern_954801', 'pattern_1108855', 'pattern_912900']
#   > RESULT: MISS. Correct ID 'pattern_998032' not found.
#
# --- Batch recommendation complete. ---
#
# ================== FINAL RESULTS ==================
# Total Images Processed: 50
# Total Hits (Recall@10): 8
# Average Accuracy (R@10): 16.00%
# Average Query Time: 4.9549 ms
# =================================================

# %%
import os
import pickle
import hnswlib
import numpy as np
import time

# --- Configuration ---
test_image_folder = 'Evaluation_Sweaters/cardigans'
valid_image_extensions = ('.jpg', '.jpeg', '.png')

num_recommendations = 10


# --- Load HNSWlib index and pattern IDs ---
try:
    print(f"Loading pattern IDs from {pattern_ids_file}...")
    with open(pattern_ids_file, 'rb') as f:
        pattern_ids = pickle.load(f)

    print(f"Loading HNSWlib index from {index_file}...")
    num_elements = len(pattern_ids)
    
    hnsw_index = hnswlib.Index(space='cosine', dim=feature_dim)
    hnsw_index.load_index(index_file, max_elements=num_elements)
    
    hnsw_index.set_ef(1000) 
    print(f"Index loaded successfully. Set efSearch = 1000")
        
except (IOError, RuntimeError) as e:
    print(f"Error loading files: {e}")
    print("Please ensure you have run your index-building script first.")
    exit()

# --- Lists to store results for averaging ---
all_query_times_ms = []
all_hits = [] # 1 for a hit, 0 for a miss

# --- Run Recommendation for all images in the folder ---
if not os.path.isdir(test_image_folder):
    print(f"Error: Test image folder not found at '{test_image_folder}'")
else:
    print(f"\n--- Starting batch recommendation for all images in {test_image_folder} ---")
    
    # Get a clean list of just the image files
    image_files_to_process = [
        f for f in sorted(os.listdir(test_image_folder)) 
        if f.lower().endswith(valid_image_extensions)
    ]
    total_images = len(image_files_to_process)
    
    if total_images == 0:
        print(f"No valid images found in {test_image_folder}")
        exit()

    for i, image_filename in enumerate(image_files_to_process):
        
        test_image_path = os.path.join(test_image_folder, image_filename)
        print(f"\n=============================================")
        print(f"Testing Image {i+1}/{total_images}: {image_filename}")
        print(f"=============================================")
        
        try:
            # --- Step 1: Get the correct pattern ID from the filename ---
            
            # Get the ID (e.g., "123456") from the filename (e.g., "123456.jpg")
            id_from_file = image_filename.split('.')[0] # <-- CHANGED
            
            # Format it to match the IDs in your pattern_ids list (e.g., "pattern_123456")
            correct_pattern_id = f"pattern_{id_from_file}" # <-- CHANGED
            
            print(f"  > Ground Truth ID: {correct_pattern_id}")

            # --- Step 2: Extract features for the query image ---
            img_path_out, query_vector = extract_features(test_image_path)
            
            if not isinstance(query_vector, np.ndarray):
                print(f"  > ERROR: Failed to extract features. Skipping.")
                print(f"  > Details: {query_vector}")
                continue 

            # --- Step 3: Run the query and time it ---
            start_time = time.perf_counter()
            labels, distances = hnsw_index.knn_query(query_vector, k=num_recommendations)
            end_time = time.perf_counter()
            
            query_time_ms = (end_time - start_time) * 1000 
            all_query_times_ms.append(query_time_ms)
            print(f"  > Query Time: {query_time_ms:.4f} ms")

            # --- Step 4: Check for a "hit" ---
            recommended_pattern_ids = [pattern_ids[i] for i in labels[0]]
            print(f"  > Recommendations: {recommended_pattern_ids}")
            
            # This check will now compare "pattern_123456" with the list
            if correct_pattern_id in recommended_pattern_ids:
                all_hits.append(1)
                print(f"  > RESULT: HIT! Correct ID '{correct_pattern_id}' was found.")
            else:
                all_hits.append(0)
                print(f"  > RESULT: MISS. Correct ID '{correct_pattern_id}' not found.")
                
        except Exception as e:
            print(f"ERROR: Could not process {image_filename}: {e}")

    # --- End of loop ---

    print("\n--- Batch recommendation complete. ---")

    # --- Calculate and print final averages ---
    if not all_hits:
        print("No images were processed successfully.")
    else:
        total_processed = len(all_hits)
        num_hits = np.sum(all_hits)
        avg_accuracy = (num_hits / total_processed) * 100
        avg_time = np.mean(all_query_times_ms)
        
        print("\n================== FINAL RESULTS ==================")
        print(f"Total Images Processed: {total_processed}")
        print(f"Total Hits (Recall@{num_recommendations}): {num_hits}")
        print(f"Average Accuracy (R@{num_recommendations}): {avg_accuracy:.2f}%")
        print(f"Average Query Time: {avg_time:.4f} ms")
        print("=================================================")
# Out:
# Loading pattern IDs from pattern_ids.pkl...
# Loading HNSWlib index from sweater_hnsw_ResNet50.bin...
# Index loaded successfully. Set efSearch = 1000
#
# --- Starting batch recommendation for all images in Evaluation_Sweaters/cardigans ---
#
# =============================================
# Testing Image 1/50: 100136.jpeg
# =============================================
#   > Ground Truth ID: pattern_100136
# Final crop size: width=281, height=346
# Original size: width=468, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/100136.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#   > Query Time: 4.8348 ms
#   > Recommendations: ['pattern_100136', 'pattern_80854', 'pattern_8603', 'pattern_55483', 'pattern_5956', 'pattern_5029', 'pattern_1000790', 'pattern_67637', 'pattern_171', 'pattern_1094753']
#   > RESULT: HIT! Correct ID 'pattern_100136' was found.
#
# =============================================
# Testing Image 2/50: 1028254.jpeg
# =============================================
#   > Ground Truth ID: pattern_1028254
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 5.2557 ms
#   > Recommendations: ['pattern_671840', 'pattern_477615', 'pattern_554684', 'pattern_497226', 'pattern_702413', 'pattern_604493', 'pattern_397915', 'pattern_206025', 'pattern_547831', 'pattern_29608']
#   > RESULT: MISS. Correct ID 'pattern_1028254' not found.
#
# =============================================
# Testing Image 3/50: 1030902.jpeg
# =============================================
#   > Ground Truth ID: pattern_1030902
#   -> Pose failed. Fallback crop (Segment) for Evaluation_Sweaters/cardigans/1030902.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 4.5924 ms
#   > Recommendations: ['pattern_112155', 'pattern_604493', 'pattern_17017', 'pattern_1294213', 'pattern_1239270', 'pattern_1339420', 'pattern_559640', 'pattern_746749', 'pattern_1269031', 'pattern_1248830']
#   > RESULT: MISS. Correct ID 'pattern_1030902' not found.
#
# =============================================
# Testing Image 4/50: 103910.jpeg
# =============================================
#   > Ground Truth ID: pattern_103910
# Final crop size: width=158, height=260
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/103910.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 4.8210 ms
#   > Recommendations: ['pattern_1082', 'pattern_707964', 'pattern_1245554', 'pattern_849752', 'pattern_1944', 'pattern_289061', 'pattern_206025', 'pattern_22837', 'pattern_1315479', 'pattern_264547']
#   > RESULT: MISS. Correct ID 'pattern_103910' not found.
#
# =============================================
# Testing Image 5/50: 110719.jpg
# =============================================
#   > Ground Truth ID: pattern_110719
# Final crop size: width=338, height=482
# Original size: width=640, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/110719.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#   > Query Time: 4.3505 ms
#   > Recommendations: ['pattern_718850', 'pattern_249316', 'pattern_537455', 'pattern_401115', 'pattern_1292542', 'pattern_171758', 'pattern_275144', 'pattern_191', 'pattern_1613', 'pattern_28821']
#   > RESULT: MISS. Correct ID 'pattern_110719' not found.
#
# =============================================
# Testing Image 6/50: 1119779.jpeg
# =============================================
#   > Ground Truth ID: pattern_1119779
# Final crop size: width=336, height=476
# Original size: width=478, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1119779.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#   > Query Time: 5.1067 ms
#   > Recommendations: ['pattern_994991', 'pattern_1127965', 'pattern_722275', 'pattern_1270074', 'pattern_509829', 'pattern_1118482', 'pattern_16779', 'pattern_7386750', 'pattern_1129633', 'pattern_1216351']
#   > RESULT: MISS. Correct ID 'pattern_1119779' not found.
#
# =============================================
# Testing Image 7/50: 117490.jpg
# =============================================
#   > Ground Truth ID: pattern_117490
# Final crop size: width=458, height=535
# Original size: width=640, height=550
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/117490.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 4.7719 ms
#   > Recommendations: ['pattern_1460', 'pattern_236582', 'pattern_7314683', 'pattern_7289924', 'pattern_322134', 'pattern_7364513', 'pattern_663405', 'pattern_416645', 'pattern_1071562', 'pattern_640263']
#   > RESULT: MISS. Correct ID 'pattern_117490' not found.
#
# =============================================
# Testing Image 8/50: 1196042.jpeg
# =============================================
#   > Ground Truth ID: pattern_1196042
# Final crop size: width=217, height=406
# Original size: width=431, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1196042.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.9711 ms
#   > Recommendations: ['pattern_571883', 'pattern_592913', 'pattern_1171694', 'pattern_540144', 'pattern_7368188', 'pattern_7296618', 'pattern_1138339', 'pattern_1360001', 'pattern_581854', 'pattern_896615']
#   > RESULT: MISS. Correct ID 'pattern_1196042' not found.
#
# =============================================
# Testing Image 9/50: 1215387.jpeg
# =============================================
#   > Ground Truth ID: pattern_1215387
# Final crop size: width=410, height=626
# Original size: width=624, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1215387.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.8281 ms
#   > Recommendations: ['pattern_1215387', 'pattern_62963', 'pattern_7314683', 'pattern_548916', 'pattern_7289924', 'pattern_267', 'pattern_7415405', 'pattern_63701', 'pattern_12529', 'pattern_602732']
#   > RESULT: HIT! Correct ID 'pattern_1215387' was found.
#
# =============================================
# Testing Image 10/50: 1232630.jpg
# =============================================
#   > Ground Truth ID: pattern_1232630
# Final crop size: width=575, height=636
# Original size: width=640, height=636
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1232630.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.8958 ms
#   > Recommendations: ['pattern_912926', 'pattern_13938', 'pattern_1224319', 'pattern_1071483', 'pattern_592915', 'pattern_15479', 'pattern_607771', 'pattern_30881', 'pattern_396541', 'pattern_1036695']
#   > RESULT: MISS. Correct ID 'pattern_1232630' not found.
#
# =============================================
# Testing Image 11/50: 1259525.jpeg
# =============================================
#   > Ground Truth ID: pattern_1259525
# Final crop size: width=358, height=563
# Original size: width=516, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1259525.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 5.1248 ms
#   > Recommendations: ['pattern_1124482', 'pattern_404969', 'pattern_1171374', 'pattern_932139', 'pattern_1071483', 'pattern_131876', 'pattern_135', 'pattern_1325636', 'pattern_10870', 'pattern_967318']
#   > RESULT: MISS. Correct ID 'pattern_1259525' not found.
#
# =============================================
# Testing Image 12/50: 1325806.jpeg
# =============================================
#   > Ground Truth ID: pattern_1325806
# Final crop size: width=175, height=260
# Original size: width=360, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1325806.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 7.7043 ms
#   > Recommendations: ['pattern_851584', 'pattern_875160', 'pattern_1308545', 'pattern_932139', 'pattern_7372262', 'pattern_881582', 'pattern_1327281', 'pattern_1244593', 'pattern_396541', 'pattern_1302768']
#   > RESULT: MISS. Correct ID 'pattern_1325806' not found.
#
# =============================================
# Testing Image 13/50: 132943.jpg
# =============================================
#   > Ground Truth ID: pattern_132943
# Final crop size: width=213, height=343
# Original size: width=375, height=500
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/132943.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 5.4437 ms
#   > Recommendations: ['pattern_132943', 'pattern_1137468', 'pattern_1429', 'pattern_2594', 'pattern_1354387', 'pattern_1227867', 'pattern_979641', 'pattern_393326', 'pattern_1308526', 'pattern_424124']
#   > RESULT: HIT! Correct ID 'pattern_132943' was found.
#
# =============================================
# Testing Image 14/50: 1354721.jpg
# =============================================
#   > Ground Truth ID: pattern_1354721
# Final crop size: width=144, height=287
# Original size: width=298, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1354721.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.7748 ms
#   > Recommendations: ['pattern_875724', 'pattern_256386', 'pattern_7383485', 'pattern_1012417', 'pattern_7321519', 'pattern_336549', 'pattern_1031325', 'pattern_1093235', 'pattern_375054', 'pattern_7302196']
#   > RESULT: MISS. Correct ID 'pattern_1354721' not found.
#
# =============================================
# Testing Image 15/50: 13579.jpg
# =============================================
#   > Ground Truth ID: pattern_13579
# Final crop size: width=259, height=395
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/13579.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 5.3660 ms
#   > Recommendations: ['pattern_1243773', 'pattern_640263', 'pattern_1051939', 'pattern_1056277', 'pattern_1045450', 'pattern_7361416', 'pattern_442281', 'pattern_432272', 'pattern_937964', 'pattern_987391']
#   > RESULT: MISS. Correct ID 'pattern_13579' not found.
#
# =============================================
# Testing Image 16/50: 181149.jpeg
# =============================================
#   > Ground Truth ID: pattern_181149
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 5.1754 ms
#   > Recommendations: ['pattern_908673', 'pattern_1071842', 'pattern_1079660', 'pattern_905515', 'pattern_427074', 'pattern_150361', 'pattern_823026', 'pattern_1013075', 'pattern_1173261', 'pattern_536063']
#   > RESULT: MISS. Correct ID 'pattern_181149' not found.
#
# =============================================
# Testing Image 17/50: 188479.jpg
# =============================================
#   > Ground Truth ID: pattern_188479
# Final crop size: width=252, height=540
# Original size: width=490, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/188479.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 4.9382 ms
#   > Recommendations: ['pattern_1124482', 'pattern_7398741', 'pattern_7361416', 'pattern_1000704', 'pattern_7283556', 'pattern_7328995', 'pattern_1183899', 'pattern_7373215', 'pattern_1183056', 'pattern_1327281']
#   > RESULT: MISS. Correct ID 'pattern_188479' not found.
#
# =============================================
# Testing Image 18/50: 294112.jpeg
# =============================================
#   > Ground Truth ID: pattern_294112
#   -> Pose failed. Fallback crop (Segment) for Evaluation_Sweaters/cardigans/294112.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#   > Query Time: 4.8372 ms
#   > Recommendations: ['pattern_7409734', 'pattern_1135503', 'pattern_869411', 'pattern_97286', 'pattern_191217', 'pattern_74210', 'pattern_9414', 'pattern_416105', 'pattern_66', 'pattern_6792']
#   > RESULT: MISS. Correct ID 'pattern_294112' not found.
#
# =============================================
# Testing Image 19/50: 328610.jpg
# =============================================
#   > Ground Truth ID: pattern_328610
# Final crop size: width=151, height=276
# Original size: width=427, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/328610.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 4.8636 ms
#   > Recommendations: ['pattern_7392773', 'pattern_7381791', 'pattern_7416853', 'pattern_7376371', 'pattern_864821', 'pattern_858154', 'pattern_730351', 'pattern_415265', 'pattern_1179733', 'pattern_453695']
#   > RESULT: MISS. Correct ID 'pattern_328610' not found.
#
# =============================================
# Testing Image 20/50: 330366.jpeg
# =============================================
#   > Ground Truth ID: pattern_330366
# Final crop size: width=332, height=568
# Original size: width=562, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/330366.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 5.4301 ms
#   > Recommendations: ['pattern_871619', 'pattern_330366', 'pattern_515718', 'pattern_7373722', 'pattern_504541', 'pattern_372012', 'pattern_1000528', 'pattern_1191831', 'pattern_605121', 'pattern_431963']
#   > RESULT: HIT! Correct ID 'pattern_330366' was found.
#
# =============================================
# Testing Image 21/50: 33875.jpeg
# =============================================
#   > Ground Truth ID: pattern_33875
# Final crop size: width=254, height=398
# Original size: width=640, height=480
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/33875.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 4.8687 ms
#   > Recommendations: ['pattern_2987', 'pattern_533819', 'pattern_935855', 'pattern_23114', 'pattern_6254', 'pattern_1120647', 'pattern_117490', 'pattern_1012349', 'pattern_458066', 'pattern_596471']
#   > RESULT: MISS. Correct ID 'pattern_33875' not found.
#
# =============================================
# Testing Image 22/50: 397061.jpg
# =============================================
#   > Ground Truth ID: pattern_397061
# Final crop size: width=281, height=490
# Original size: width=479, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/397061.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.6523 ms
#   > Recommendations: ['pattern_973416', 'pattern_773337', 'pattern_1105725', 'pattern_7432813', 'pattern_1061545', 'pattern_7308711', 'pattern_732717', 'pattern_425315', 'pattern_579457', 'pattern_859729']
#   > RESULT: MISS. Correct ID 'pattern_397061' not found.
#
# =============================================
# Testing Image 23/50: 412034.jpg
# =============================================
#   > Ground Truth ID: pattern_412034
# Final crop size: width=143, height=308
# Original size: width=360, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/412034.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 4.6195 ms
#   > Recommendations: ['pattern_952516', 'pattern_206746', 'pattern_977350', 'pattern_403638', 'pattern_723362', 'pattern_618858', 'pattern_7416752', 'pattern_7352868', 'pattern_583708', 'pattern_1275271']
#   > RESULT: MISS. Correct ID 'pattern_412034' not found.
#
# =============================================
# Testing Image 24/50: 425614.jpeg
# =============================================
#   > Ground Truth ID: pattern_425614
# Final crop size: width=368, height=622
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/425614.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#   > Query Time: 4.8968 ms
#   > Recommendations: ['pattern_1367912', 'pattern_7409734', 'pattern_7374471', 'pattern_328258', 'pattern_156877', 'pattern_7353380', 'pattern_1064490', 'pattern_454795', 'pattern_475526', 'pattern_416105']
#   > RESULT: MISS. Correct ID 'pattern_425614' not found.
#
# =============================================
# Testing Image 25/50: 467200.jpeg
# =============================================
#   > Ground Truth ID: pattern_467200
# Final crop size: width=289, height=431
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/467200.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.8771 ms
#   > Recommendations: ['pattern_1166279', 'pattern_1271136', 'pattern_7461632', 'pattern_105606', 'pattern_944044', 'pattern_11565', 'pattern_2535', 'pattern_613913', 'pattern_7342548', 'pattern_186253']
#   > RESULT: MISS. Correct ID 'pattern_467200' not found.
#
# =============================================
# Testing Image 26/50: 479305.jpg
# =============================================
#   > Ground Truth ID: pattern_479305
# Final crop size: width=225, height=423
# Original size: width=327, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/479305.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 4.7156 ms
#   > Recommendations: ['pattern_479305', 'pattern_1179102', 'pattern_55977', 'pattern_1370923', 'pattern_1166433', 'pattern_7376646', 'pattern_637863', 'pattern_1313919', 'pattern_222454', 'pattern_607198']
#   > RESULT: HIT! Correct ID 'pattern_479305' was found.
#
# =============================================
# Testing Image 27/50: 559137.jpg
# =============================================
#   > Ground Truth ID: pattern_559137
# Final crop size: width=176, height=280
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/559137.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#   > Query Time: 4.8274 ms
#   > Recommendations: ['pattern_892712', 'pattern_1313919', 'pattern_561322', 'pattern_801188', 'pattern_479305', 'pattern_815463', 'pattern_1370923', 'pattern_7361340', 'pattern_301081', 'pattern_233320']
#   > RESULT: MISS. Correct ID 'pattern_559137' not found.
#
# =============================================
# Testing Image 28/50: 559270.jpeg
# =============================================
#   > Ground Truth ID: pattern_559270
# Final crop size: width=163, height=256
# Original size: width=360, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/559270.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.7256 ms
#   > Recommendations: ['pattern_1242444', 'pattern_7289161', 'pattern_1127073', 'pattern_626327', 'pattern_1305588', 'pattern_778760', 'pattern_17017', 'pattern_966254', 'pattern_755747', 'pattern_1340154']
#   > RESULT: MISS. Correct ID 'pattern_559270' not found.
#
# =============================================
# Testing Image 29/50: 591693.jpeg
# =============================================
#   > Ground Truth ID: pattern_591693
# Final crop size: width=233, height=409
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/591693.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 5.1227 ms
#   > Recommendations: ['pattern_202924', 'pattern_414694', 'pattern_231950', 'pattern_582758', 'pattern_516008', 'pattern_7292266', 'pattern_536502', 'pattern_516136', 'pattern_387300', 'pattern_140154']
#   > RESULT: MISS. Correct ID 'pattern_591693' not found.
#
# =============================================
# Testing Image 30/50: 602276.jpeg
# =============================================
#   > Ground Truth ID: pattern_602276
# Final crop size: width=525, height=588
# Original size: width=637, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/602276.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 5.2943 ms
#   > Recommendations: ['pattern_1014316', 'pattern_746749', 'pattern_554684', 'pattern_7368188', 'pattern_7284139', 'pattern_131876', 'pattern_624175', 'pattern_997785', 'pattern_962103', 'pattern_7352871']
#   > RESULT: MISS. Correct ID 'pattern_602276' not found.
#
# =============================================
# Testing Image 31/50: 636345.jpg
# =============================================
#   > Ground Truth ID: pattern_636345
# Final crop size: width=133, height=206
# Original size: width=278, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/636345.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 5.0370 ms
#   > Recommendations: ['pattern_7459194', 'pattern_801188', 'pattern_900563', 'pattern_889407', 'pattern_116647', 'pattern_1015665', 'pattern_416068', 'pattern_770576', 'pattern_872919', 'pattern_620052']
#   > RESULT: MISS. Correct ID 'pattern_636345' not found.
#
# =============================================
# Testing Image 32/50: 681431.jpeg
# =============================================
#   > Ground Truth ID: pattern_681431
# Final crop size: width=204, height=330
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/681431.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 4.8525 ms
#   > Recommendations: ['pattern_81434', 'pattern_603007', 'pattern_650354', 'pattern_1326687', 'pattern_1429', 'pattern_7398741', 'pattern_330800', 'pattern_1072150', 'pattern_958225', 'pattern_935855']
#   > RESULT: MISS. Correct ID 'pattern_681431' not found.
#
# =============================================
# Testing Image 33/50: 686943.jpg
# =============================================
#   > Ground Truth ID: pattern_686943
# Final crop size: width=506, height=480
# Original size: width=640, height=480
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/686943.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 5.0615 ms
#   > Recommendations: ['pattern_274849', 'pattern_44410', 'pattern_397061', 'pattern_170724', 'pattern_1012995', 'pattern_326110', 'pattern_10126', 'pattern_346214', 'pattern_487079', 'pattern_246114']
#   > RESULT: MISS. Correct ID 'pattern_686943' not found.
#
# =============================================
# Testing Image 34/50: 711607.jpg
# =============================================
#   > Ground Truth ID: pattern_711607
# Final crop size: width=133, height=206
# Original size: width=278, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/711607.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 5.1635 ms
#   > Recommendations: ['pattern_7459194', 'pattern_801188', 'pattern_900563', 'pattern_889407', 'pattern_116647', 'pattern_1015665', 'pattern_416068', 'pattern_770576', 'pattern_872919', 'pattern_620052']
#   > RESULT: MISS. Correct ID 'pattern_711607' not found.
#
# =============================================
# Testing Image 35/50: 7292988.jpeg
# =============================================
#   > Ground Truth ID: pattern_7292988
# Final crop size: width=414, height=561
# Original size: width=476, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/7292988.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.7487 ms
#   > Recommendations: ['pattern_887917', 'pattern_10937', 'pattern_41464', 'pattern_15218', 'pattern_1068555', 'pattern_87913', 'pattern_6792', 'pattern_17520', 'pattern_2987', 'pattern_11565']
#   > RESULT: MISS. Correct ID 'pattern_7292988' not found.
#
# =============================================
# Testing Image 36/50: 733855.jpeg
# =============================================
#   > Ground Truth ID: pattern_733855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 4.9561 ms
#   > Recommendations: ['pattern_7386750', 'pattern_691983', 'pattern_912900', 'pattern_1169993', 'pattern_864171', 'pattern_690062', 'pattern_1129633', 'pattern_560800', 'pattern_705893', 'pattern_23411']
#   > RESULT: MISS. Correct ID 'pattern_733855' not found.
#
# =============================================
# Testing Image 37/50: 7348838.jpg
# =============================================
#   > Ground Truth ID: pattern_7348838
# Final crop size: width=367, height=605
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/7348838.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 5.0335 ms
#   > Recommendations: ['pattern_1319836', 'pattern_1071483', 'pattern_7348838', 'pattern_1281925', 'pattern_924790', 'pattern_7282717', 'pattern_1302397', 'pattern_7289251', 'pattern_1186830', 'pattern_7344372']
#   > RESULT: HIT! Correct ID 'pattern_7348838' was found.
#
# =============================================
# Testing Image 38/50: 7392773.jpeg
# =============================================
#   > Ground Truth ID: pattern_7392773
# Final crop size: width=315, height=463
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/7392773.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 5.1042 ms
#   > Recommendations: ['pattern_43940', 'pattern_1105725', 'pattern_1036695', 'pattern_773337', 'pattern_39003', 'pattern_732717', 'pattern_1282948', 'pattern_1227567', 'pattern_1107361', 'pattern_1071483']
#   > RESULT: MISS. Correct ID 'pattern_7392773' not found.
#
# =============================================
# Testing Image 39/50: 76823.jpeg
# =============================================
#   > Ground Truth ID: pattern_76823
# Final crop size: width=294, height=458
# Original size: width=466, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/76823.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 5.1096 ms
#   > Recommendations: ['pattern_229196', 'pattern_170724', 'pattern_7358367', 'pattern_312123', 'pattern_579501', 'pattern_256842', 'pattern_753580', 'pattern_1243136', 'pattern_7374471', 'pattern_17292']
#   > RESULT: MISS. Correct ID 'pattern_76823' not found.
#
# =============================================
# Testing Image 40/50: 796740.jpeg
# =============================================
#   > Ground Truth ID: pattern_796740
# Final crop size: width=290, height=416
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/796740.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 4.0752 ms
#   > Recommendations: ['pattern_18322', 'pattern_411956', 'pattern_329395', 'pattern_18193', 'pattern_1269031', 'pattern_1088190', 'pattern_1210277', 'pattern_1127073', 'pattern_77627', 'pattern_1115643']
#   > RESULT: MISS. Correct ID 'pattern_796740' not found.
#
# =============================================
# Testing Image 41/50: 803939.jpeg
# =============================================
#   > Ground Truth ID: pattern_803939
# Final crop size: width=283, height=403
# Original size: width=512, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/803939.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 5.5034 ms
#   > Recommendations: ['pattern_7283556', 'pattern_1192496', 'pattern_169386', 'pattern_1029757', 'pattern_320688', 'pattern_981278', 'pattern_1083921', 'pattern_1312521', 'pattern_1032762', 'pattern_1321843']
#   > RESULT: MISS. Correct ID 'pattern_803939' not found.
#
# =============================================
# Testing Image 42/50: 804035.jpg
# =============================================
#   > Ground Truth ID: pattern_804035
# Final crop size: width=312, height=480
# Original size: width=640, height=480
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/804035.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 5.0148 ms
#   > Recommendations: ['pattern_522912', 'pattern_396541', 'pattern_62695', 'pattern_978408', 'pattern_1068017', 'pattern_222454', 'pattern_1124482', 'pattern_439753', 'pattern_543012', 'pattern_446422']
#   > RESULT: MISS. Correct ID 'pattern_804035' not found.
#
# =============================================
# Testing Image 43/50: 813991.jpg
# =============================================
#   > Ground Truth ID: pattern_813991
# Final crop size: width=371, height=597
# Original size: width=482, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/813991.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 4.3456 ms
#   > Recommendations: ['pattern_324187', 'pattern_22785', 'pattern_7855', 'pattern_668', 'pattern_15596', 'pattern_86334', 'pattern_38607', 'pattern_583745', 'pattern_815857', 'pattern_12529']
#   > RESULT: MISS. Correct ID 'pattern_813991' not found.
#
# =============================================
# Testing Image 44/50: 844144.jpg
# =============================================
#   > Ground Truth ID: pattern_844144
# Final crop size: width=361, height=556
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/844144.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 5.1272 ms
#   > Recommendations: ['pattern_1019395', 'pattern_753580', 'pattern_158411', 'pattern_1325801', 'pattern_653498', 'pattern_1080890', 'pattern_22044', 'pattern_1278515', 'pattern_564348', 'pattern_108023']
#   > RESULT: MISS. Correct ID 'pattern_844144' not found.
#
# =============================================
# Testing Image 45/50: 9042.jpeg
# =============================================
#   > Ground Truth ID: pattern_9042
#   -> Pose failed. Fallback crop (Segment) for Evaluation_Sweaters/cardigans/9042.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 5.2057 ms
#   > Recommendations: ['pattern_1293451', 'pattern_887917', 'pattern_1274367', 'pattern_7296386', 'pattern_11380', 'pattern_1105725', 'pattern_1294213', 'pattern_1085319', 'pattern_773337', 'pattern_253471']
#   > RESULT: MISS. Correct ID 'pattern_9042' not found.
#
# =============================================
# Testing Image 46/50: 914227.jpeg
# =============================================
#   > Ground Truth ID: pattern_914227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 5.4990 ms
#   > Recommendations: ['pattern_914227', 'pattern_853098', 'pattern_243870', 'pattern_479943', 'pattern_1037082', 'pattern_478973', 'pattern_233089', 'pattern_344768', 'pattern_1209887', 'pattern_63144']
#   > RESULT: HIT! Correct ID 'pattern_914227' was found.
#
# =============================================
# Testing Image 47/50: 922057.jpg
# =============================================
#   > Ground Truth ID: pattern_922057
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 5.0941 ms
#   > Recommendations: ['pattern_1347892', 'pattern_1191248', 'pattern_691983', 'pattern_908673', 'pattern_1071842', 'pattern_1144145', 'pattern_83278', 'pattern_1217389', 'pattern_7289213', 'pattern_1085250']
#   > RESULT: MISS. Correct ID 'pattern_922057' not found.
#
# =============================================
# Testing Image 48/50: 933944.jpeg
# =============================================
#   > Ground Truth ID: pattern_933944
# Final crop size: width=253, height=420
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/933944.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#   > Query Time: 4.8830 ms
#   > Recommendations: ['pattern_7432813', 'pattern_78720', 'pattern_749768', 'pattern_7379837', 'pattern_1216557', 'pattern_4293', 'pattern_7294343', 'pattern_1340146', 'pattern_1298238', 'pattern_938626']
#   > RESULT: MISS. Correct ID 'pattern_933944' not found.
#
# =============================================
# Testing Image 49/50: 949096.jpeg
# =============================================
#   > Ground Truth ID: pattern_949096
# Final crop size: width=141, height=213
# Original size: width=480, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/949096.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#   > Query Time: 5.2689 ms
#   > Recommendations: ['pattern_949096', 'pattern_1170258', 'pattern_1167760', 'pattern_1274411', 'pattern_1278116', 'pattern_1368247', 'pattern_579029', 'pattern_219162', 'pattern_1043048', 'pattern_309159']
#   > RESULT: HIT! Correct ID 'pattern_949096' was found.
#
# =============================================
# Testing Image 50/50: 997785.jpeg
# =============================================
#   > Ground Truth ID: pattern_997785
# Final crop size: width=288, height=456
# Original size: width=640, height=640
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/997785.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#   > Query Time: 4.8145 ms
#   > Recommendations: ['pattern_7432813', 'pattern_7291766', 'pattern_1252234', 'pattern_1354803', 'pattern_7319576', 'pattern_160903', 'pattern_1130250', 'pattern_1263903', 'pattern_1212620', 'pattern_1124482']
#   > RESULT: MISS. Correct ID 'pattern_997785' not found.
#
# --- Batch recommendation complete. ---
#
# ================== FINAL RESULTS ==================
# Total Images Processed: 50
# Total Hits (Recall@10): 8
# Average Accuracy (R@10): 16.00%
# Average Query Time: 5.0117 ms
# =================================================
