# %%
# search_hnsw.py
import hnswlib
import pickle
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os
from resnet_feature_extraction import extract_features # Your existing function

# --- Configuration ---
index_file = 'sweater_hnsw_resnet_yolo_pose_multicentroid.bin'
pattern_ids_file = 'centroid_to_pattern_resnet_yolo_pose.pkl'
feature_dim = 2048 # Should match the dimension used for building the index

def recommend_similar_images(query_image_path, hnsw_index, pattern_ids, num_recommendations=5):
    """
    Finds and displays the most similar images to a query image using an HNSWlib index.
    """
    print(f"--- Generating recommendations for {os.path.basename(query_image_path)} ---")
    
    # --- 1. Extract features from the query image ---
    _, query_vector = extract_features(query_image_path)
    if query_vector is None or not isinstance(query_vector, np.ndarray):
        print(f"Could not extract features from {query_image_path}")
        return

    # HNSWlib requires a 1D or 2D array, and it must be float32
    query_vector = np.array(query_vector).astype('float32')
    
    # --- 2. Search the HNSWlib index ---
    # The knn_query method returns labels and distances for the k nearest neighbors
    labels, distances = hnsw_index.knn_query(query_vector, k=num_recommendations)

    # The result is a 2D array, so we get the first (and only) row
    neighbor_indices = labels[0]
    
    print(f"Found neighbors with indices: {neighbor_indices}")
    
    # --- 3. Display the results ---
    plt.figure(figsize=(15, 5))

    # Display Query Image
    ax = plt.subplot(1, num_recommendations + 1, 1)
    query_img = Image.open(query_image_path)
    ax.imshow(query_img)
    ax.set_title("Query Image")
    ax.axis("off")

    # Display Recommended Images
    for i, idx in enumerate(neighbor_indices):
        recommended_pattern_id = pattern_ids[idx]
        
        # IMPORTANT: Update this path to how your images are stored.
        # This example assumes a structure like: data_directory/pattern_id/image.jpg
        rec_img_folder = os.path.join('/Volumes/Extreme Pro/ANN_photos', recommended_pattern_id)
        
        # Find the first image in the recommended pattern folder to display
        try:
            image_files = [f for f in os.listdir(rec_img_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
            if not image_files:
                print(f"Warning: No images found for pattern {recommended_pattern_id}.")
                continue
            first_image_file = image_files[0]
            rec_img_path = os.path.join(rec_img_folder, first_image_file)

            ax = plt.subplot(1, num_recommendations + 1, i + 2)
            rec_img = Image.open(rec_img_path)
            ax.imshow(rec_img)
            ax.set_title(f'Rec #{i+1}\n{recommended_pattern_id}')
            ax.axis('off')
        except (IOError, IndexError) as e:
            print(f"Warning: Could not load image for pattern {recommended_pattern_id}. Error: {e}")


    plt.tight_layout()
    plt.show()
# Out:
# Initializing model...
# Model initialized.

# %%
import os
import pickle
import hnswlib
import numpy as np
import time

# --- Configuration ---
test_image_folder = 'Evaluation_Sweaters/pullovers'
valid_image_extensions = ('.jpg', '.jpeg', '.png')

feature_dim = 2048 # Should match the dimension used for building the index
num_recommendations = 10


# --- Load HNSWlib index and pattern IDs ---
try:
    print(f"Loading pattern IDs from {pattern_ids_file}...")
    with open(pattern_ids_file, 'rb') as f:
        pattern_ids = pickle.load(f)

    print(f"Loading HNSWlib index from {index_file}...")
    num_elements = len(pattern_ids)
    
    hnsw_index = hnswlib.Index(space='cosine', dim=feature_dim)
    hnsw_index.load_index(index_file, max_elements=num_elements)
    
    hnsw_index.set_ef(1000) 
    print(f"Index loaded successfully. Set efSearch = 1000")
        
except (IOError, RuntimeError) as e:
    print(f"Error loading files: {e}")
    print("Please ensure you have run your index-building script first.")
    exit()

# --- Lists to store results for averaging ---
all_query_times_ms = []
all_hits = [] # 1 for a hit, 0 for a miss

# --- Run Recommendation for all images in the folder ---
if not os.path.isdir(test_image_folder):
    print(f"Error: Test image folder not found at '{test_image_folder}'")
else:
    print(f"\n--- Starting batch recommendation for all images in {test_image_folder} ---")
    
    # Get a clean list of just the image files
    image_files_to_process = [
        f for f in sorted(os.listdir(test_image_folder)) 
        if f.lower().endswith(valid_image_extensions)
    ]
    total_images = len(image_files_to_process)
    
    if total_images == 0:
        print(f"No valid images found in {test_image_folder}")
        exit()

    for i, image_filename in enumerate(image_files_to_process):
        
        test_image_path = os.path.join(test_image_folder, image_filename)
        print(f"\n=============================================")
        print(f"Testing Image {i+1}/{total_images}: {image_filename}")
        print(f"=============================================")
        
        try:
            # --- Step 1: Get the correct pattern ID from the filename ---
            
            # Get the ID (e.g., "123456") from the filename (e.g., "123456.jpg")
            id_from_file = image_filename.split('.')[0] # <-- CHANGED
            
            # Format it to match the IDs in your pattern_ids list (e.g., "pattern_123456")
            correct_pattern_id = f"pattern_{id_from_file}" # <-- CHANGED
            
            print(f"  > Ground Truth ID: {correct_pattern_id}")

            # --- Step 2: Extract features for the query image ---
            img_path_out, query_vector = extract_features(test_image_path)
            
            if not isinstance(query_vector, np.ndarray):
                print(f"  > ERROR: Failed to extract features. Skipping.")
                print(f"  > Details: {query_vector}")
                continue 

            # --- Step 3: Run the query and time it ---
            start_time = time.perf_counter()
            labels, distances = hnsw_index.knn_query(query_vector, k=num_recommendations)
            end_time = time.perf_counter()
            
            query_time_ms = (end_time - start_time) * 1000 
            all_query_times_ms.append(query_time_ms)
            print(f"  > Query Time: {query_time_ms:.4f} ms")

            # --- Step 4: Check for a "hit" ---
            recommended_pattern_ids = [pattern_ids[i] for i in labels[0]]
            print(f"  > Recommendations: {recommended_pattern_ids}")
            
            # This check will now compare "pattern_123456" with the list
            if correct_pattern_id in recommended_pattern_ids:
                all_hits.append(1)
                print(f"  > RESULT: HIT! Correct ID '{correct_pattern_id}' was found.")
            else:
                all_hits.append(0)
                print(f"  > RESULT: MISS. Correct ID '{correct_pattern_id}' not found.")
                
        except Exception as e:
            print(f"ERROR: Could not process {image_filename}: {e}")

    # --- End of loop ---

    print("\n--- Batch recommendation complete. ---")

    # --- Calculate and print final averages ---
    if not all_hits:
        print("No images were processed successfully.")
    else:
        total_processed = len(all_hits)
        num_hits = np.sum(all_hits)
        avg_accuracy = (num_hits / total_processed) * 100
        avg_time = np.mean(all_query_times_ms)
        
        print("\n================== FINAL RESULTS ==================")
        print(f"Total Images Processed: {total_processed}")
        print(f"Total Hits (Recall@{num_recommendations}): {num_hits}")
        print(f"Average Accuracy (R@{num_recommendations}): {avg_accuracy:.2f}%")
        print(f"Average Query Time: {avg_time:.4f} ms")
        print("=================================================")
# Out:
# Loading pattern IDs from centroid_to_pattern_resnet_yolo_pose.pkl...
# Loading HNSWlib index from sweater_hnsw_resnet_yolo_pose_multicentroid.bin...
# Index loaded successfully. Set efSearch = 1000
#
# --- Starting batch recommendation for all images in Evaluation_Sweaters/pullovers ---
#
# =============================================
# Testing Image 1/50: 1001132.jpeg
# =============================================
#   > Ground Truth ID: pattern_1001132
#   -> Keypoint crop: 4 keypoints, size=318x480
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1001132.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#   > Query Time: 15.8393 ms
#   > Recommendations: ['pattern_673961', 'pattern_7341634', 'pattern_247632', 'pattern_7431667', 'pattern_7375130', 'pattern_204950', 'pattern_982885', 'pattern_1077466', 'pattern_1194262', 'pattern_7377058']
#   > RESULT: MISS. Correct ID 'pattern_1001132' not found.
#
# =============================================
# Testing Image 2/50: 100437.jpeg
# =============================================
#   > Ground Truth ID: pattern_100437
#   -> Keypoint crop: 4 keypoints, size=303x592
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/100437.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 16.3882 ms
#   > Recommendations: ['pattern_903167', 'pattern_704757', 'pattern_814164', 'pattern_470169', 'pattern_840171', 'pattern_1208237', 'pattern_974559', 'pattern_814340', 'pattern_1154885', 'pattern_723693']
#   > RESULT: MISS. Correct ID 'pattern_100437' not found.
#
# =============================================
# Testing Image 3/50: 1021796.jpeg
# =============================================
#   > Ground Truth ID: pattern_1021796
#   -> Crop too small (74x361). Falling back to segmentation.
#   -> Pose failed. Fallback crop (Segment) for Evaluation_Sweaters/pullovers/1021796.jpeg
#   -> Segmentation crop: size=377x375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 15.2367 ms
#   > Recommendations: ['pattern_1289140', 'pattern_988101', 'pattern_1208116', 'pattern_1017658', 'pattern_1118241', 'pattern_395774', 'pattern_790309', 'pattern_478226', 'pattern_688103', 'pattern_1194262']
#   > RESULT: MISS. Correct ID 'pattern_1021796' not found.
#
# =============================================
# Testing Image 4/50: 1037791.jpeg
# =============================================
#   > Ground Truth ID: pattern_1037791
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > Query Time: 15.4628 ms
#   > Recommendations: ['pattern_723693', 'pattern_1061338', 'pattern_939945', 'pattern_130899', 'pattern_814340', 'pattern_903989', 'pattern_858730', 'pattern_1341013', 'pattern_783068', 'pattern_932512']
#   > RESULT: MISS. Correct ID 'pattern_1037791' not found.
#
# =============================================
# Testing Image 5/50: 1066129.jpeg
# =============================================
#   > Ground Truth ID: pattern_1066129
#   -> Keypoint crop: 4 keypoints, size=434x596
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1066129.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > Query Time: 16.3633 ms
#   > Recommendations: ['pattern_395774', 'pattern_1208116', 'pattern_857338', 'pattern_912900', 'pattern_883608', 'pattern_931325', 'pattern_720284', 'pattern_7306431', 'pattern_675518', 'pattern_1194502']
#   > RESULT: MISS. Correct ID 'pattern_1066129' not found.
#
# =============================================
# Testing Image 6/50: 1094188.png
# =============================================
#   > Ground Truth ID: pattern_1094188
#   -> Keypoint crop: 4 keypoints, size=142x248
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1094188.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 15.0726 ms
#   > Recommendations: ['pattern_1323310', 'pattern_7322842', 'pattern_7431590', 'pattern_439219', 'pattern_7324048', 'pattern_7458140', 'pattern_1075946', 'pattern_7459904', 'pattern_7287712', 'pattern_1307528']
#   > RESULT: MISS. Correct ID 'pattern_1094188' not found.
#
# =============================================
# Testing Image 7/50: 1105965.jpeg
# =============================================
#   > Ground Truth ID: pattern_1105965
#   -> Keypoint crop: 4 keypoints, size=198x345
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1105965.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 17.2067 ms
#   > Recommendations: ['pattern_1194502', 'pattern_1006258', 'pattern_7344372', 'pattern_542225', 'pattern_7410094', 'pattern_516136', 'pattern_7367566', 'pattern_7341366', 'pattern_1318354', 'pattern_972398']
#   > RESULT: MISS. Correct ID 'pattern_1105965' not found.
#
# =============================================
# Testing Image 8/50: 1115643.jpeg
# =============================================
#   > Ground Truth ID: pattern_1115643
#   -> Keypoint crop: 4 keypoints, size=246x338
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1115643.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 17.8779 ms
#   > Recommendations: ['pattern_1316343', 'pattern_1115474', 'pattern_1278012', 'pattern_7357117', 'pattern_1332531', 'pattern_7368013', 'pattern_1207248', 'pattern_1019400', 'pattern_7372262', 'pattern_7371636']
#   > RESULT: MISS. Correct ID 'pattern_1115643' not found.
#
# =============================================
# Testing Image 9/50: 1118466.jpeg
# =============================================
#   > Ground Truth ID: pattern_1118466
#   -> Keypoint crop: 4 keypoints, size=304x416
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1118466.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 16.5144 ms
#   > Recommendations: ['pattern_728386', 'pattern_775740', 'pattern_974559', 'pattern_1095803', 'pattern_903167', 'pattern_973363', 'pattern_778932', 'pattern_1121800', 'pattern_814164', 'pattern_704757']
#   > RESULT: MISS. Correct ID 'pattern_1118466' not found.
#
# =============================================
# Testing Image 10/50: 1138136.jpeg
# =============================================
#   > Ground Truth ID: pattern_1138136
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 17.8035 ms
#   > Recommendations: ['pattern_552612', 'pattern_516362', 'pattern_1086941', 'pattern_553748', 'pattern_7299690', 'pattern_763850', 'pattern_912900', 'pattern_954549', 'pattern_922415', 'pattern_554421']
#   > RESULT: MISS. Correct ID 'pattern_1138136' not found.
#
# =============================================
# Testing Image 11/50: 1175440.jpg
# =============================================
#   > Ground Truth ID: pattern_1175440
#   -> Keypoint crop: 4 keypoints, size=325x555
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1175440.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 18.0805 ms
#   > Recommendations: ['pattern_480871', 'pattern_1043234', 'pattern_837542', 'pattern_1138657', 'pattern_924996', 'pattern_481291', 'pattern_494597', 'pattern_738816', 'pattern_7400425', 'pattern_1144252']
#   > RESULT: MISS. Correct ID 'pattern_1175440' not found.
#
# =============================================
# Testing Image 12/50: 1242444.jpeg
# =============================================
#   > Ground Truth ID: pattern_1242444
#   -> Keypoint crop: 4 keypoints, size=247x402
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1242444.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 18.3204 ms
#   > Recommendations: ['pattern_1081479', 'pattern_1246316', 'pattern_986748', 'pattern_1085622', 'pattern_7410094', 'pattern_7324048', 'pattern_7458140', 'pattern_875160', 'pattern_1192350', 'pattern_299886']
#   > RESULT: MISS. Correct ID 'pattern_1242444' not found.
#
# =============================================
# Testing Image 13/50: 1245286.jpeg
# =============================================
#   > Ground Truth ID: pattern_1245286
#   -> Keypoint crop: 4 keypoints, size=184x344
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1245286.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 15.5254 ms
#   > Recommendations: ['pattern_1332531', 'pattern_1204473', 'pattern_1323310', 'pattern_1031394', 'pattern_7324048', 'pattern_1338453', 'pattern_7322842', 'pattern_1216697', 'pattern_1004205', 'pattern_704829']
#   > RESULT: MISS. Correct ID 'pattern_1245286' not found.
#
# =============================================
# Testing Image 14/50: 1261520.jpeg
# =============================================
#   > Ground Truth ID: pattern_1261520
#   -> Keypoint crop: 4 keypoints, size=316x427
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1261520.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 15.6318 ms
#   > Recommendations: ['pattern_7282717', 'pattern_7368013', 'pattern_7344372', 'pattern_7342548', 'pattern_1115474', 'pattern_7287712', 'pattern_7322842', 'pattern_1332531', 'pattern_7341672', 'pattern_7342548']
#   > RESULT: MISS. Correct ID 'pattern_1261520' not found.
#
# =============================================
# Testing Image 15/50: 1269391.jpeg
# =============================================
#   > Ground Truth ID: pattern_1269391
#   -> Keypoint crop: 4 keypoints, size=338x532
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1269391.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 15.6515 ms
#   > Recommendations: ['pattern_1217370', 'pattern_751423', 'pattern_7390056', 'pattern_1316343', 'pattern_1138101', 'pattern_1040101', 'pattern_1155036', 'pattern_1147272', 'pattern_7364191', 'pattern_1140505']
#   > RESULT: MISS. Correct ID 'pattern_1269391' not found.
#
# =============================================
# Testing Image 16/50: 1269666.jpeg
# =============================================
#   > Ground Truth ID: pattern_1269666
#   -> Keypoint crop: 4 keypoints, size=235x381
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1269666.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 14.3647 ms
#   > Recommendations: ['pattern_1037791', 'pattern_991497', 'pattern_1130007', 'pattern_1013659', 'pattern_996729', 'pattern_1121800', 'pattern_1295950', 'pattern_1189679', 'pattern_800080', 'pattern_1028894']
#   > RESULT: MISS. Correct ID 'pattern_1269666' not found.
#
# =============================================
# Testing Image 17/50: 1273349.jpeg
# =============================================
#   > Ground Truth ID: pattern_1273349
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 19.6891 ms
#   > Recommendations: ['pattern_1215387', 'pattern_794359', 'pattern_1129874', 'pattern_1323565', 'pattern_658135', 'pattern_665518', 'pattern_1332531', 'pattern_1066011', 'pattern_1084877', 'pattern_7287712']
#   > RESULT: MISS. Correct ID 'pattern_1273349' not found.
#
# =============================================
# Testing Image 18/50: 1277038.jpeg
# =============================================
#   > Ground Truth ID: pattern_1277038
#   -> Keypoint crop: 4 keypoints, size=185x295
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1277038.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 17.1823 ms
#   > Recommendations: ['pattern_7387340', 'pattern_1077466', 'pattern_273472', 'pattern_637273', 'pattern_650108', 'pattern_1113258', 'pattern_1102968', 'pattern_1147272', 'pattern_595925', 'pattern_1325801']
#   > RESULT: MISS. Correct ID 'pattern_1277038' not found.
#
# =============================================
# Testing Image 19/50: 1309104.jpeg
# =============================================
#   > Ground Truth ID: pattern_1309104
#   -> Keypoint crop: 4 keypoints, size=226x367
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1309104.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 14.5883 ms
#   > Recommendations: ['pattern_537939', 'pattern_537939', 'pattern_247632', 'pattern_1171694', 'pattern_7302370', 'pattern_903047', 'pattern_1233729', 'pattern_814606', 'pattern_972398', 'pattern_1194262']
#   > RESULT: MISS. Correct ID 'pattern_1309104' not found.
#
# =============================================
# Testing Image 20/50: 1314562.jpeg
# =============================================
#   > Ground Truth ID: pattern_1314562
#   -> Keypoint crop: 4 keypoints, size=365x407
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1314562.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 16.7187 ms
#   > Recommendations: ['pattern_837488', 'pattern_1276274', 'pattern_350832', 'pattern_1316343', 'pattern_7450443', 'pattern_671234', 'pattern_395234', 'pattern_584877', 'pattern_7450443', 'pattern_518471']
#   > RESULT: MISS. Correct ID 'pattern_1314562' not found.
#
# =============================================
# Testing Image 21/50: 1318255.jpeg
# =============================================
#   > Ground Truth ID: pattern_1318255
#   -> Keypoint crop: 4 keypoints, size=136x211
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1318255.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 16.6886 ms
#   > Recommendations: ['pattern_1318255', 'pattern_1191831', 'pattern_1059510', 'pattern_1081479', 'pattern_1023773', 'pattern_1074016', 'pattern_7431667', 'pattern_7298554', 'pattern_1323987', 'pattern_1332531']
#   > RESULT: HIT! Correct ID 'pattern_1318255' was found.
#
# =============================================
# Testing Image 22/50: 1321524.jpeg
# =============================================
#   > Ground Truth ID: pattern_1321524
#   -> Keypoint crop: 4 keypoints, size=228x311
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/1321524.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 15.4689 ms
#   > Recommendations: ['pattern_1309093', 'pattern_7335505', 'pattern_1157225', 'pattern_575229', 'pattern_1064757', 'pattern_837488', 'pattern_1260158', 'pattern_1326902', 'pattern_1160343', 'pattern_1241181']
#   > RESULT: MISS. Correct ID 'pattern_1321524' not found.
#
# =============================================
# Testing Image 23/50: 13854.jpeg
# =============================================
#   > Ground Truth ID: pattern_13854
#   -> Keypoint crop: 4 keypoints, size=309x490
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/13854.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 15.8553 ms
#   > Recommendations: ['pattern_260937', 'pattern_937640', 'pattern_347755', 'pattern_288446', 'pattern_620309', 'pattern_125050', 'pattern_556602', 'pattern_560150', 'pattern_643969', 'pattern_351510']
#   > RESULT: MISS. Correct ID 'pattern_13854' not found.
#
# =============================================
# Testing Image 24/50: 141029.jpeg
# =============================================
#   > Ground Truth ID: pattern_141029
#   -> Keypoint crop: 4 keypoints, size=133x204
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/141029.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 13.9225 ms
#   > Recommendations: ['pattern_7367566', 'pattern_1351034', 'pattern_949200', 'pattern_7418682', 'pattern_1010478', 'pattern_673961', 'pattern_1262218', 'pattern_920587', 'pattern_1282994', 'pattern_774796']
#   > RESULT: MISS. Correct ID 'pattern_141029' not found.
#
# =============================================
# Testing Image 25/50: 276617.jpg
# =============================================
#   > Ground Truth ID: pattern_276617
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 11.7843 ms
#   > Recommendations: ['pattern_722275', 'pattern_11721', 'pattern_1172623', 'pattern_879967', 'pattern_1084323', 'pattern_1218906', 'pattern_1195408', 'pattern_1294130', 'pattern_1274367', 'pattern_16448']
#   > RESULT: MISS. Correct ID 'pattern_276617' not found.
#
# =============================================
# Testing Image 26/50: 303674.jpeg
# =============================================
#   > Ground Truth ID: pattern_303674
#   -> Keypoint crop: 4 keypoints, size=319x437
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/303674.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > Query Time: 17.3620 ms
#   > Recommendations: ['pattern_1279061', 'pattern_390437', 'pattern_1017564', 'pattern_1043234', 'pattern_863819', 'pattern_553748', 'pattern_1072755', 'pattern_9641', 'pattern_738816', 'pattern_745201']
#   > RESULT: MISS. Correct ID 'pattern_303674' not found.
#
# =============================================
# Testing Image 27/50: 363242.jpeg
# =============================================
#   > Ground Truth ID: pattern_363242
#   -> Keypoint crop: 4 keypoints, size=357x519
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/363242.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 14.8259 ms
#   > Recommendations: ['pattern_466331', 'pattern_954549', 'pattern_994876', 'pattern_7292607', 'pattern_839122', 'pattern_903989', 'pattern_1037791', 'pattern_1066011', 'pattern_1328963', 'pattern_673961']
#   > RESULT: MISS. Correct ID 'pattern_363242' not found.
#
# =============================================
# Testing Image 28/50: 381119.jpeg
# =============================================
#   > Ground Truth ID: pattern_381119
#   -> Keypoint crop: 4 keypoints, size=224x331
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/381119.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 14.1367 ms
#   > Recommendations: ['pattern_751423', 'pattern_839122', 'pattern_673961', 'pattern_537939', 'pattern_1328930', 'pattern_716559', 'pattern_1163272', 'pattern_969683', 'pattern_7387340', 'pattern_1254723']
#   > RESULT: MISS. Correct ID 'pattern_381119' not found.
#
# =============================================
# Testing Image 29/50: 446142.jpeg
# =============================================
#   > Ground Truth ID: pattern_446142
#   -> Crop too small (452x11). Falling back to segmentation.
#   -> Pose failed. Fallback crop (Segment) for Evaluation_Sweaters/pullovers/446142.jpeg
#   -> Segmentation crop: size=480x640
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 14.6428 ms
#   > Recommendations: ['pattern_1017658', 'pattern_108016', 'pattern_1218906', 'pattern_1318354', 'pattern_1119767', 'pattern_7341634', 'pattern_242355', 'pattern_517327', 'pattern_7352871', 'pattern_786730']
#   > RESULT: MISS. Correct ID 'pattern_446142' not found.
#
# =============================================
# Testing Image 30/50: 473885.jpeg
# =============================================
#   > Ground Truth ID: pattern_473885
#   -> Keypoint crop: 4 keypoints, size=196x392
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/473885.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 16.8631 ms
#   > Recommendations: ['pattern_650108', 'pattern_572662', 'pattern_792335', 'pattern_1085622', 'pattern_680547', 'pattern_557799', 'pattern_875160', 'pattern_650108', 'pattern_671840', 'pattern_1093554']
#   > RESULT: MISS. Correct ID 'pattern_473885' not found.
#
# =============================================
# Testing Image 31/50: 491132.jpeg
# =============================================
#   > Ground Truth ID: pattern_491132
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 13.7350 ms
#   > Recommendations: ['pattern_7326639', 'pattern_553748', 'pattern_1274656', 'pattern_1227867', 'pattern_7367129', 'pattern_877616', 'pattern_721744', 'pattern_1195408', 'pattern_935593', 'pattern_853098']
#   > RESULT: MISS. Correct ID 'pattern_491132' not found.
#
# =============================================
# Testing Image 32/50: 543344.jpg
# =============================================
#   > Ground Truth ID: pattern_543344
#   -> Keypoint crop: 4 keypoints, size=338x374
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/543344.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 19.8761 ms
#   > Recommendations: ['pattern_1034320', 'pattern_858814', 'pattern_7379837', 'pattern_7327948', 'pattern_1175350', 'pattern_1036695', 'pattern_352455', 'pattern_1292756', 'pattern_1126711', 'pattern_1357939']
#   > RESULT: MISS. Correct ID 'pattern_543344' not found.
#
# =============================================
# Testing Image 33/50: 585377.jpg
# =============================================
#   > Ground Truth ID: pattern_585377
#   -> Keypoint crop: 4 keypoints, size=311x408
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/585377.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 17.3288 ms
#   > Recommendations: ['pattern_1013214', 'pattern_812992', 'pattern_390437', 'pattern_266030', 'pattern_459582', 'pattern_10120', 'pattern_65457', 'pattern_1279061', 'pattern_1204473', 'pattern_1043234']
#   > RESULT: MISS. Correct ID 'pattern_585377' not found.
#
# =============================================
# Testing Image 34/50: 5870.jpeg
# =============================================
#   > Ground Truth ID: pattern_5870
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 13.4703 ms
#   > Recommendations: ['pattern_1267757', 'pattern_1233729', 'pattern_950482', 'pattern_8625', 'pattern_1107361', 'pattern_984125', 'pattern_994861', 'pattern_41464', 'pattern_1323310', 'pattern_1164938']
#   > RESULT: MISS. Correct ID 'pattern_5870' not found.
#
# =============================================
# Testing Image 35/50: 639347.jpeg
# =============================================
#   > Ground Truth ID: pattern_639347
#   -> Keypoint crop: 4 keypoints, size=214x332
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/639347.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 17.5351 ms
#   > Recommendations: ['pattern_969683', 'pattern_466331', 'pattern_1138101', 'pattern_1262218', 'pattern_397915', 'pattern_7377058', 'pattern_1085146', 'pattern_763850', 'pattern_7462784', 'pattern_913969']
#   > RESULT: MISS. Correct ID 'pattern_639347' not found.
#
# =============================================
# Testing Image 36/50: 663573.jpeg
# =============================================
#   > Ground Truth ID: pattern_663573
#   -> Keypoint crop: 4 keypoints, size=176x317
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/663573.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 17.5791 ms
#   > Recommendations: ['pattern_1144252', 'pattern_1328012', 'pattern_1351034', 'pattern_1144252', 'pattern_1138657', 'pattern_827978', 'pattern_1279061', 'pattern_1134812', 'pattern_858814', 'pattern_1034280']
#   > RESULT: MISS. Correct ID 'pattern_663573' not found.
#
# =============================================
# Testing Image 37/50: 7296687.jpeg
# =============================================
#   > Ground Truth ID: pattern_7296687
#   -> Keypoint crop: 4 keypoints, size=438x620
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/7296687.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 17.2330 ms
#   > Recommendations: ['pattern_1028894', 'pattern_1323159', 'pattern_645868', 'pattern_772597', 'pattern_1130007', 'pattern_903167', 'pattern_728386', 'pattern_980654', 'pattern_7299184', 'pattern_7299184']
#   > RESULT: MISS. Correct ID 'pattern_7296687' not found.
#
# =============================================
# Testing Image 38/50: 7303862.jpeg
# =============================================
#   > Ground Truth ID: pattern_7303862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 19.1927 ms
#   > Recommendations: ['pattern_1269031', 'pattern_1332053', 'pattern_1147272', 'pattern_7431667', 'pattern_7458140', 'pattern_1322063', 'pattern_1072572', 'pattern_7335505', 'pattern_1342787', 'pattern_7329175']
#   > RESULT: MISS. Correct ID 'pattern_7303862' not found.
#
# =============================================
# Testing Image 39/50: 7311058.jpg
# =============================================
#   > Ground Truth ID: pattern_7311058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 17.4617 ms
#   > Recommendations: ['pattern_1059900', 'pattern_7445743', 'pattern_1065160', 'pattern_1330052', 'pattern_1100830', 'pattern_7287712', 'pattern_7357117', 'pattern_862427', 'pattern_979641', 'pattern_7462784']
#   > RESULT: MISS. Correct ID 'pattern_7311058' not found.
#
# =============================================
# Testing Image 40/50: 7313250.jpeg
# =============================================
#   > Ground Truth ID: pattern_7313250
#   -> Keypoint crop: 4 keypoints, size=351x513
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/7313250.jpeg
#   -> Result was 100.0% black. Falling back to original image.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 19.1064 ms
#   > Recommendations: ['pattern_903989', 'pattern_1092437', 'pattern_989328', 'pattern_7364976', 'pattern_1311076', 'pattern_1310361', 'pattern_1140505', 'pattern_7282717', 'pattern_1360502', 'pattern_922415']
#   > RESULT: MISS. Correct ID 'pattern_7313250' not found.
#
# =============================================
# Testing Image 41/50: 7384360.jpg
# =============================================
#   > Ground Truth ID: pattern_7384360
#   -> Keypoint crop: 4 keypoints, size=276x352
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/7384360.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 18.0123 ms
#   > Recommendations: ['pattern_1342787', 'pattern_1084877', 'pattern_7364976', 'pattern_1012685', 'pattern_1194502', 'pattern_7373408', 'pattern_1341013', 'pattern_1086589', 'pattern_1353351', 'pattern_894651']
#   > RESULT: MISS. Correct ID 'pattern_7384360' not found.
#
# =============================================
# Testing Image 42/50: 817885.jpeg
# =============================================
#   > Ground Truth ID: pattern_817885
#   -> Keypoint crop: 4 keypoints, size=338x606
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/817885.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 15.9570 ms
#   > Recommendations: ['pattern_1316343', 'pattern_1328012', 'pattern_1070475', 'pattern_7431667', 'pattern_969683', 'pattern_839122', 'pattern_481291', 'pattern_673961', 'pattern_1328930', 'pattern_1144252']
#   > RESULT: MISS. Correct ID 'pattern_817885' not found.
#
# =============================================
# Testing Image 43/50: 817988.jpeg
# =============================================
#   > Ground Truth ID: pattern_817988
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 12.4903 ms
#   > Recommendations: ['pattern_912900', 'pattern_691983', 'pattern_1000704', 'pattern_1040492', 'pattern_1113224', 'pattern_935593', 'pattern_7465247', 'pattern_7285419', 'pattern_7311540', 'pattern_7341634']
#   > RESULT: MISS. Correct ID 'pattern_817988' not found.
#
# =============================================
# Testing Image 44/50: 858135.jpeg
# =============================================
#   > Ground Truth ID: pattern_858135
#   -> Keypoint crop: 4 keypoints, size=360x525
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/858135.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > Query Time: 15.2222 ms
#   > Recommendations: ['pattern_130899', 'pattern_1217370', 'pattern_7390056', 'pattern_1012685', 'pattern_395774', 'pattern_986748', 'pattern_857338', 'pattern_1037791', 'pattern_1147272', 'pattern_1227362']
#   > RESULT: MISS. Correct ID 'pattern_858135' not found.
#
# =============================================
# Testing Image 45/50: 871033.jpeg
# =============================================
#   > Ground Truth ID: pattern_871033
#   -> Keypoint crop: 4 keypoints, size=256x381
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/871033.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 15.6800 ms
#   > Recommendations: ['pattern_972398', 'pattern_439010', 'pattern_7431590', 'pattern_7302370', 'pattern_975050', 'pattern_7324661', 'pattern_7364191', 'pattern_839122', 'pattern_1316343', 'pattern_7399626']
#   > RESULT: MISS. Correct ID 'pattern_871033' not found.
#
# =============================================
# Testing Image 46/50: 873566.jpg
# =============================================
#   > Ground Truth ID: pattern_873566
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 12.2848 ms
#   > Recommendations: ['pattern_1304873', 'pattern_914227', 'pattern_873566', 'pattern_1068017', 'pattern_805933', 'pattern_912900', 'pattern_7326639', 'pattern_1344089', 'pattern_978889', 'pattern_1218906']
#   > RESULT: HIT! Correct ID 'pattern_873566' was found.
#
# =============================================
# Testing Image 47/50: 873567.jpg
# =============================================
#   > Ground Truth ID: pattern_873567
#   -> Keypoint crop: 4 keypoints, size=133x226
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/873567.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > Query Time: 15.2346 ms
#   > Recommendations: ['pattern_7367566', 'pattern_552150', 'pattern_1034309', 'pattern_7399626', 'pattern_7391050', 'pattern_7458140', 'pattern_994876', 'pattern_1238361', 'pattern_886064', 'pattern_524561']
#   > RESULT: MISS. Correct ID 'pattern_873567' not found.
#
# =============================================
# Testing Image 48/50: 901966.jpg
# =============================================
#   > Ground Truth ID: pattern_901966
#   -> Crop too small (133x639). Falling back to segmentation.
#   -> Pose failed. Fallback crop (Segment) for Evaluation_Sweaters/pullovers/901966.jpg
#   -> Segmentation crop: size=542x640
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 17.3356 ms
#   > Recommendations: ['pattern_1034309', 'pattern_1238361', 'pattern_1217370', 'pattern_1318354', 'pattern_1316343', 'pattern_7415052', 'pattern_1206916', 'pattern_7322002', 'pattern_883608', 'pattern_1086012']
#   > RESULT: MISS. Correct ID 'pattern_901966' not found.
#
# =============================================
# Testing Image 49/50: 971112.jpeg
# =============================================
#   > Ground Truth ID: pattern_971112
#   -> Keypoint crop: 4 keypoints, size=417x585
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/971112.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 17.6235 ms
#   > Recommendations: ['pattern_7462784', 'pattern_1357939', 'pattern_969683', 'pattern_7390056', 'pattern_537939', 'pattern_1084877', 'pattern_1106464', 'pattern_7415052', 'pattern_7368013', 'pattern_1318354']
#   > RESULT: MISS. Correct ID 'pattern_971112' not found.
#
# =============================================
# Testing Image 50/50: 998032.jpeg
# =============================================
#   > Ground Truth ID: pattern_998032
#   -> Keypoint crop: 4 keypoints, size=220x410
#   -> Smart crop (Pose) for Evaluation_Sweaters/pullovers/998032.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 14.9439 ms
#   > Recommendations: ['pattern_972398', 'pattern_1233729', 'pattern_7292607', 'pattern_7317421', 'pattern_1328963', 'pattern_7289251', 'pattern_1217370', 'pattern_988101', 'pattern_1123541', 'pattern_7415052']
#   > RESULT: MISS. Correct ID 'pattern_998032' not found.
#
# --- Batch recommendation complete. ---
#
# ================== FINAL RESULTS ==================
# Total Images Processed: 50
# Total Hits (Recall@10): 2
# Average Accuracy (R@10): 4.00%
# Average Query Time: 16.1674 ms
# =================================================

# %%
import os
import pickle
import hnswlib
import numpy as np
import time

# --- Configuration ---
test_image_folder = 'Evaluation_Sweaters/cardigans'
valid_image_extensions = ('.jpg', '.jpeg', '.png')
num_recommendations = 10

# --- Load HNSWlib index and pattern IDs ---
try:
    print(f"Loading pattern IDs from {pattern_ids_file}...")
    with open(pattern_ids_file, 'rb') as f:
        pattern_ids = pickle.load(f)

    print(f"Loading HNSWlib index from {index_file}...")
    num_elements = len(pattern_ids)
    
    hnsw_index = hnswlib.Index(space='cosine', dim=feature_dim)
    hnsw_index.load_index(index_file, max_elements=num_elements)
    
    hnsw_index.set_ef(1000) 
    print(f"Index loaded successfully. Set efSearch = 1000")
        
except (IOError, RuntimeError) as e:
    print(f"Error loading files: {e}")
    print("Please ensure you have run your index-building script first.")
    exit()

# --- Lists to store results for averaging ---
all_query_times_ms = []
all_hits = [] # 1 for a hit, 0 for a miss

# --- Run Recommendation for all images in the folder ---
if not os.path.isdir(test_image_folder):
    print(f"Error: Test image folder not found at '{test_image_folder}'")
else:
    print(f"\n--- Starting batch recommendation for all images in {test_image_folder} ---")
    
    # Get a clean list of just the image files
    image_files_to_process = [
        f for f in sorted(os.listdir(test_image_folder)) 
        if f.lower().endswith(valid_image_extensions)
    ]
    total_images = len(image_files_to_process)
    
    if total_images == 0:
        print(f"No valid images found in {test_image_folder}")
        exit()

    for i, image_filename in enumerate(image_files_to_process):
        
        test_image_path = os.path.join(test_image_folder, image_filename)
        print(f"\n=============================================")
        print(f"Testing Image {i+1}/{total_images}: {image_filename}")
        print(f"=============================================")
        
        try:
            # --- Step 1: Get the correct pattern ID from the filename ---
            
            # Get the ID (e.g., "123456") from the filename (e.g., "123456.jpg")
            id_from_file = image_filename.split('.')[0] # <-- CHANGED
            
            # Format it to match the IDs in your pattern_ids list (e.g., "pattern_123456")
            correct_pattern_id = f"pattern_{id_from_file}" # <-- CHANGED
            
            print(f"  > Ground Truth ID: {correct_pattern_id}")

            # --- Step 2: Extract features for the query image ---
            img_path_out, query_vector = extract_features(test_image_path)
            
            if not isinstance(query_vector, np.ndarray):
                print(f"  > ERROR: Failed to extract features. Skipping.")
                print(f"  > Details: {query_vector}")
                continue 

            # --- Step 3: Run the query and time it ---
            start_time = time.perf_counter()
            labels, distances = hnsw_index.knn_query(query_vector, k=num_recommendations)
            end_time = time.perf_counter()
            
            query_time_ms = (end_time - start_time) * 1000 
            all_query_times_ms.append(query_time_ms)
            print(f"  > Query Time: {query_time_ms:.4f} ms")

            # --- Step 4: Check for a "hit" ---
            recommended_pattern_ids = [pattern_ids[i] for i in labels[0]]
            print(f"  > Recommendations: {recommended_pattern_ids}")
            
            # This check will now compare "pattern_123456" with the list
            if correct_pattern_id in recommended_pattern_ids:
                all_hits.append(1)
                print(f"  > RESULT: HIT! Correct ID '{correct_pattern_id}' was found.")
            else:
                all_hits.append(0)
                print(f"  > RESULT: MISS. Correct ID '{correct_pattern_id}' not found.")
                
        except Exception as e:
            print(f"ERROR: Could not process {image_filename}: {e}")

    # --- End of loop ---

    print("\n--- Batch recommendation complete. ---")

    # --- Calculate and print final averages ---
    if not all_hits:
        print("No images were processed successfully.")
    else:
        total_processed = len(all_hits)
        num_hits = np.sum(all_hits)
        avg_accuracy = (num_hits / total_processed) * 100
        avg_time = np.mean(all_query_times_ms)
        
        print("\n================== FINAL RESULTS ==================")
        print(f"Total Images Processed: {total_processed}")
        print(f"Total Hits (Recall@{num_recommendations}): {num_hits}")
        print(f"Average Accuracy (R@{num_recommendations}): {avg_accuracy:.2f}%")
        print(f"Average Query Time: {avg_time:.4f} ms")
        print("=================================================")
# Out:
# Loading pattern IDs from centroid_to_pattern_resnet_yolo_pose.pkl...
# Loading HNSWlib index from sweater_hnsw_resnet_yolo_pose_multicentroid.bin...
# Index loaded successfully. Set efSearch = 1000
#
# --- Starting batch recommendation for all images in Evaluation_Sweaters/cardigans ---
#
# =============================================
# Testing Image 1/50: 100136.jpeg
# =============================================
#   > Ground Truth ID: pattern_100136
#   -> Keypoint crop: 4 keypoints, size=281x346
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/100136.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 19.6082 ms
#   > Recommendations: ['pattern_944366', 'pattern_854034', 'pattern_1225168', 'pattern_1279061', 'pattern_1024686', 'pattern_1217370', 'pattern_658135', 'pattern_1094753', 'pattern_322800', 'pattern_1282994']
#   > RESULT: MISS. Correct ID 'pattern_100136' not found.
#
# =============================================
# Testing Image 2/50: 1028254.jpeg
# =============================================
#   > Ground Truth ID: pattern_1028254
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 16.1196 ms
#   > Recommendations: ['pattern_1196039', 'pattern_1274367', 'pattern_512075', 'pattern_394564', 'pattern_7352871', 'pattern_773337', 'pattern_651365', 'pattern_322800', 'pattern_721744', 'pattern_994991']
#   > RESULT: MISS. Correct ID 'pattern_1028254' not found.
#
# =============================================
# Testing Image 3/50: 1030902.jpeg
# =============================================
#   > Ground Truth ID: pattern_1030902
#   -> Crop too small (500x20). Falling back to segmentation.
#   -> Pose failed. Fallback crop (Segment) for Evaluation_Sweaters/cardigans/1030902.jpeg
#   -> Segmentation crop: size=500x500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 15.4802 ms
#   > Recommendations: ['pattern_1000704', 'pattern_7345845', 'pattern_7352871', 'pattern_790309', 'pattern_1038996', 'pattern_77370', 'pattern_693900', 'pattern_130899', 'pattern_1227567', 'pattern_879967']
#   > RESULT: MISS. Correct ID 'pattern_1030902' not found.
#
# =============================================
# Testing Image 4/50: 103910.jpeg
# =============================================
#   > Ground Truth ID: pattern_103910
#   -> Keypoint crop: 4 keypoints, size=158x260
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/103910.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 16.7227 ms
#   > Recommendations: ['pattern_7446189', 'pattern_7322842', 'pattern_705014', 'pattern_863020', 'pattern_329760', 'pattern_824626', 'pattern_994991', 'pattern_1077466', 'pattern_606279', 'pattern_937640']
#   > RESULT: MISS. Correct ID 'pattern_103910' not found.
#
# =============================================
# Testing Image 5/50: 110719.jpg
# =============================================
#   > Ground Truth ID: pattern_110719
#   -> Keypoint crop: 4 keypoints, size=338x482
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/110719.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > Query Time: 18.1746 ms
#   > Recommendations: ['pattern_1136335', 'pattern_7328995', 'pattern_587724', 'pattern_592029', 'pattern_815500', 'pattern_1071483', 'pattern_908306', 'pattern_435777', 'pattern_793143', 'pattern_1196042']
#   > RESULT: MISS. Correct ID 'pattern_110719' not found.
#
# =============================================
# Testing Image 6/50: 1119779.jpeg
# =============================================
#   > Ground Truth ID: pattern_1119779
#   -> Keypoint crop: 4 keypoints, size=336x476
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1119779.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 17.5075 ms
#   > Recommendations: ['pattern_1196039', 'pattern_773337', 'pattern_624731', 'pattern_1105725', 'pattern_863020', 'pattern_733765', 'pattern_773337', 'pattern_1154191', 'pattern_1216351', 'pattern_557799']
#   > RESULT: MISS. Correct ID 'pattern_1119779' not found.
#
# =============================================
# Testing Image 7/50: 117490.jpg
# =============================================
#   > Ground Truth ID: pattern_117490
#   -> Keypoint crop: 4 keypoints, size=458x535
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/117490.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > Query Time: 19.4817 ms
#   > Recommendations: ['pattern_906474', 'pattern_7412196', 'pattern_1023773', 'pattern_1071483', 'pattern_415246', 'pattern_322800', 'pattern_554684', 'pattern_757647', 'pattern_1278012', 'pattern_337716']
#   > RESULT: MISS. Correct ID 'pattern_117490' not found.
#
# =============================================
# Testing Image 8/50: 1196042.jpeg
# =============================================
#   > Ground Truth ID: pattern_1196042
#   -> Keypoint crop: 4 keypoints, size=217x406
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1196042.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 17.3463 ms
#   > Recommendations: ['pattern_7370441', 'pattern_1106369', 'pattern_1085622', 'pattern_1171694', 'pattern_879419', 'pattern_863020', 'pattern_1139994', 'pattern_7344372', 'pattern_1175699', 'pattern_7293487']
#   > RESULT: MISS. Correct ID 'pattern_1196042' not found.
#
# =============================================
# Testing Image 9/50: 1215387.jpeg
# =============================================
#   > Ground Truth ID: pattern_1215387
#   -> Keypoint crop: 4 keypoints, size=410x626
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1215387.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > Query Time: 17.0896 ms
#   > Recommendations: ['pattern_7364703', 'pattern_1350101', 'pattern_7289924', 'pattern_576067', 'pattern_1327281', 'pattern_1080345', 'pattern_904141', 'pattern_863020', 'pattern_1224319', 'pattern_1036695']
#   > RESULT: MISS. Correct ID 'pattern_1215387' not found.
#
# =============================================
# Testing Image 10/50: 1232630.jpg
# =============================================
#   > Ground Truth ID: pattern_1232630
#   -> Keypoint crop: 4 keypoints, size=575x636
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1232630.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 14.3129 ms
#   > Recommendations: ['pattern_1036695', 'pattern_7394818', 'pattern_1282948', 'pattern_396541', 'pattern_1224319', 'pattern_7283556', 'pattern_1092437', 'pattern_7289924', 'pattern_469818', 'pattern_292035']
#   > RESULT: MISS. Correct ID 'pattern_1232630' not found.
#
# =============================================
# Testing Image 11/50: 1259525.jpeg
# =============================================
#   > Ground Truth ID: pattern_1259525
#   -> Keypoint crop: 4 keypoints, size=358x563
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1259525.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 16.4448 ms
#   > Recommendations: ['pattern_1124482', 'pattern_590096', 'pattern_1012349', 'pattern_1062836', 'pattern_139408', 'pattern_1365015', 'pattern_602811', 'pattern_1302699', 'pattern_997785', 'pattern_379678']
#   > RESULT: MISS. Correct ID 'pattern_1259525' not found.
#
# =============================================
# Testing Image 12/50: 1325806.jpeg
# =============================================
#   > Ground Truth ID: pattern_1325806
#   -> Keypoint crop: 4 keypoints, size=175x260
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1325806.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > Query Time: 15.2099 ms
#   > Recommendations: ['pattern_851584', 'pattern_1005574', 'pattern_732717', 'pattern_330800', 'pattern_7444516', 'pattern_310282', 'pattern_292035', 'pattern_469818', 'pattern_1124482', 'pattern_7372262']
#   > RESULT: MISS. Correct ID 'pattern_1325806' not found.
#
# =============================================
# Testing Image 13/50: 132943.jpg
# =============================================
#   > Ground Truth ID: pattern_132943
#   -> Keypoint crop: 4 keypoints, size=213x343
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/132943.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 16.4861 ms
#   > Recommendations: ['pattern_132943', 'pattern_979641', 'pattern_1023773', 'pattern_1127434', 'pattern_986976', 'pattern_690418', 'pattern_7445743', 'pattern_7364703', 'pattern_1192496', 'pattern_960356']
#   > RESULT: HIT! Correct ID 'pattern_132943' was found.
#
# =============================================
# Testing Image 14/50: 1354721.jpg
# =============================================
#   > Ground Truth ID: pattern_1354721
#   -> Keypoint crop: 4 keypoints, size=144x287
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/1354721.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > Query Time: 18.1670 ms
#   > Recommendations: ['pattern_1289702', 'pattern_967318', 'pattern_1134812', 'pattern_658735', 'pattern_181182', 'pattern_942434', 'pattern_1012417', 'pattern_647762', 'pattern_1175350', 'pattern_1112126']
#   > RESULT: MISS. Correct ID 'pattern_1354721' not found.
#
# =============================================
# Testing Image 15/50: 13579.jpg
# =============================================
#   > Ground Truth ID: pattern_13579
#   -> Keypoint crop: 4 keypoints, size=259x395
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/13579.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 18.1641 ms
#   > Recommendations: ['pattern_7376234', 'pattern_1243773', 'pattern_960356', 'pattern_896615', 'pattern_997785', 'pattern_1038687', 'pattern_1263859', 'pattern_1175350', 'pattern_921987', 'pattern_1365015']
#   > RESULT: MISS. Correct ID 'pattern_13579' not found.
#
# =============================================
# Testing Image 16/50: 181149.jpeg
# =============================================
#   > Ground Truth ID: pattern_181149
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
#   > Query Time: 16.4274 ms
#   > Recommendations: ['pattern_1191248', 'pattern_864731', 'pattern_903989', 'pattern_736986', 'pattern_1311076', 'pattern_814340', 'pattern_516362', 'pattern_7345845', 'pattern_936508', 'pattern_1227362']
#   > RESULT: MISS. Correct ID 'pattern_181149' not found.
#
# =============================================
# Testing Image 17/50: 188479.jpg
# =============================================
#   > Ground Truth ID: pattern_188479
#   -> Keypoint crop: 4 keypoints, size=252x540
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/188479.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 17.0245 ms
#   > Recommendations: ['pattern_967318', 'pattern_247632', 'pattern_1124482', 'pattern_7341634', 'pattern_658735', 'pattern_1171694', 'pattern_7377058', 'pattern_1106464', 'pattern_1221656', 'pattern_1019400']
#   > RESULT: MISS. Correct ID 'pattern_188479' not found.
#
# =============================================
# Testing Image 18/50: 294112.jpeg
# =============================================
#   > Ground Truth ID: pattern_294112
#   -> Insufficient keypoints (1). Falling back to segmentation.
#   -> Pose failed. Fallback crop (Segment) for Evaluation_Sweaters/cardigans/294112.jpeg
#   -> Segmentation crop: size=480x640
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 13.7534 ms
#   > Recommendations: ['pattern_108016', 'pattern_1134501', 'pattern_181182', 'pattern_237842', 'pattern_805933', 'pattern_242355', 'pattern_7352871', 'pattern_295972', 'pattern_121454', 'pattern_1344089']
#   > RESULT: MISS. Correct ID 'pattern_294112' not found.
#
# =============================================
# Testing Image 19/50: 328610.jpg
# =============================================
#   > Ground Truth ID: pattern_328610
#   -> Keypoint crop: 4 keypoints, size=151x276
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/328610.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 13.9484 ms
#   > Recommendations: ['pattern_861428', 'pattern_1072150', 'pattern_850420', 'pattern_1062887', 'pattern_7322842', 'pattern_1271469', 'pattern_7344372', 'pattern_463263', 'pattern_1199988', 'pattern_812431']
#   > RESULT: MISS. Correct ID 'pattern_328610' not found.
#
# =============================================
# Testing Image 20/50: 330366.jpeg
# =============================================
#   > Ground Truth ID: pattern_330366
#   -> Keypoint crop: 4 keypoints, size=332x568
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/330366.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 16.8500 ms
#   > Recommendations: ['pattern_7282096', 'pattern_824626', 'pattern_742414', 'pattern_732717', 'pattern_1124482', 'pattern_1192496', 'pattern_7334462', 'pattern_1238097', 'pattern_999463', 'pattern_921987']
#   > RESULT: MISS. Correct ID 'pattern_330366' not found.
#
# =============================================
# Testing Image 21/50: 33875.jpeg
# =============================================
#   > Ground Truth ID: pattern_33875
#   -> Keypoint crop: 4 keypoints, size=254x398
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/33875.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 14.1840 ms
#   > Recommendations: ['pattern_7394818', 'pattern_7364703', 'pattern_7444516', 'pattern_7461632', 'pattern_1282948', 'pattern_7289924', 'pattern_1130785', 'pattern_396541', 'pattern_1036695', 'pattern_1079849']
#   > RESULT: MISS. Correct ID 'pattern_33875' not found.
#
# =============================================
# Testing Image 22/50: 397061.jpg
# =============================================
#   > Ground Truth ID: pattern_397061
#   -> Keypoint crop: 4 keypoints, size=281x490
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/397061.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 16.5509 ms
#   > Recommendations: ['pattern_7372262', 'pattern_863020', 'pattern_467657', 'pattern_516362', 'pattern_1274367', 'pattern_624731', 'pattern_7352871', 'pattern_336549', 'pattern_650108', 'pattern_1330052']
#   > RESULT: MISS. Correct ID 'pattern_397061' not found.
#
# =============================================
# Testing Image 23/50: 412034.jpg
# =============================================
#   > Ground Truth ID: pattern_412034
#   -> Keypoint crop: 4 keypoints, size=143x308
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/412034.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > Query Time: 17.2228 ms
#   > Recommendations: ['pattern_757647', 'pattern_775391', 'pattern_1037791', 'pattern_7458140', 'pattern_7344372', 'pattern_576067', 'pattern_852799', 'pattern_701637', 'pattern_1357949', 'pattern_1182083']
#   > RESULT: MISS. Correct ID 'pattern_412034' not found.
#
# =============================================
# Testing Image 24/50: 425614.jpeg
# =============================================
#   > Ground Truth ID: pattern_425614
#   -> Keypoint crop: 4 keypoints, size=368x622
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/425614.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 16.1091 ms
#   > Recommendations: ['pattern_352455', 'pattern_1176350', 'pattern_1247231', 'pattern_1147272', 'pattern_409483', 'pattern_1064490', 'pattern_7364191', 'pattern_1036695', 'pattern_763850', 'pattern_7444516']
#   > RESULT: MISS. Correct ID 'pattern_425614' not found.
#
# =============================================
# Testing Image 25/50: 467200.jpeg
# =============================================
#   > Ground Truth ID: pattern_467200
#   -> Keypoint crop: 4 keypoints, size=289x431
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/467200.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 15.7174 ms
#   > Recommendations: ['pattern_1091857', 'pattern_732717', 'pattern_7461632', 'pattern_7376234', 'pattern_1237333', 'pattern_7472210', 'pattern_1077466', 'pattern_896615', 'pattern_7326639', 'pattern_1077466']
#   > RESULT: MISS. Correct ID 'pattern_467200' not found.
#
# =============================================
# Testing Image 26/50: 479305.jpg
# =============================================
#   > Ground Truth ID: pattern_479305
#   -> Keypoint crop: 4 keypoints, size=225x423
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/479305.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 14.6070 ms
#   > Recommendations: ['pattern_1092437', 'pattern_7394818', 'pattern_7364703', 'pattern_1036695', 'pattern_1350101', 'pattern_7342182', 'pattern_732717', 'pattern_1068017', 'pattern_429365', 'pattern_7283556']
#   > RESULT: MISS. Correct ID 'pattern_479305' not found.
#
# =============================================
# Testing Image 27/50: 559137.jpg
# =============================================
#   > Ground Truth ID: pattern_559137
#   -> Keypoint crop: 4 keypoints, size=176x280
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/559137.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > Query Time: 17.3263 ms
#   > Recommendations: ['pattern_1091857', 'pattern_700088', 'pattern_511876', 'pattern_1147272', 'pattern_176863', 'pattern_1045450', 'pattern_1124482', 'pattern_7472210', 'pattern_1031325', 'pattern_1296124']
#   > RESULT: MISS. Correct ID 'pattern_559137' not found.
#
# =============================================
# Testing Image 28/50: 559270.jpeg
# =============================================
#   > Ground Truth ID: pattern_559270
#   -> Keypoint crop: 4 keypoints, size=163x256
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/559270.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 16.4530 ms
#   > Recommendations: ['pattern_557799', 'pattern_863020', 'pattern_960356', 'pattern_852799', 'pattern_875724', 'pattern_978408', 'pattern_7361416', 'pattern_855548', 'pattern_1217370', 'pattern_569871']
#   > RESULT: MISS. Correct ID 'pattern_559270' not found.
#
# =============================================
# Testing Image 29/50: 591693.jpeg
# =============================================
#   > Ground Truth ID: pattern_591693
#   -> Keypoint crop: 4 keypoints, size=233x409
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/591693.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > Query Time: 18.0105 ms
#   > Recommendations: ['pattern_783909', 'pattern_7341366', 'pattern_516136', 'pattern_7445306', 'pattern_1326687', 'pattern_1062815', 'pattern_944366', 'pattern_1074016', 'pattern_1218545', 'pattern_1163272']
#   > RESULT: MISS. Correct ID 'pattern_591693' not found.
#
# =============================================
# Testing Image 30/50: 602276.jpeg
# =============================================
#   > Ground Truth ID: pattern_602276
#   -> Keypoint crop: 4 keypoints, size=525x588
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/602276.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 16.6470 ms
#   > Recommendations: ['pattern_140180', 'pattern_419287', 'pattern_554684', 'pattern_651082', 'pattern_960356', 'pattern_237143', 'pattern_1269031', 'pattern_237241', 'pattern_581854', 'pattern_620309']
#   > RESULT: MISS. Correct ID 'pattern_602276' not found.
#
# =============================================
# Testing Image 31/50: 636345.jpg
# =============================================
#   > Ground Truth ID: pattern_636345
#   -> Keypoint crop: 4 keypoints, size=133x206
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/636345.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 16.9783 ms
#   > Recommendations: ['pattern_1365015', 'pattern_1235299', 'pattern_921987', 'pattern_922057', 'pattern_742414', 'pattern_7373215', 'pattern_1124482', 'pattern_733855', 'pattern_1175350', 'pattern_855548']
#   > RESULT: MISS. Correct ID 'pattern_636345' not found.
#
# =============================================
# Testing Image 32/50: 681431.jpeg
# =============================================
#   > Ground Truth ID: pattern_681431
#   -> Keypoint crop: 4 keypoints, size=204x330
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/681431.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 15.7607 ms
#   > Recommendations: ['pattern_679052', 'pattern_520882', 'pattern_7322842', 'pattern_921987', 'pattern_1072150', 'pattern_1175350', 'pattern_1036695', 'pattern_1365015', 'pattern_766645', 'pattern_7398741']
#   > RESULT: MISS. Correct ID 'pattern_681431' not found.
#
# =============================================
# Testing Image 33/50: 686943.jpg
# =============================================
#   > Ground Truth ID: pattern_686943
#   -> Keypoint crop: 4 keypoints, size=506x480
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/686943.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > Query Time: 16.8456 ms
#   > Recommendations: ['pattern_326110', 'pattern_181182', 'pattern_1068555', 'pattern_560150', 'pattern_7344546', 'pattern_960356', 'pattern_487896', 'pattern_594059', 'pattern_572662', 'pattern_242355']
#   > RESULT: MISS. Correct ID 'pattern_686943' not found.
#
# =============================================
# Testing Image 34/50: 711607.jpg
# =============================================
#   > Ground Truth ID: pattern_711607
#   -> Keypoint crop: 4 keypoints, size=133x206
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/711607.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 15.3938 ms
#   > Recommendations: ['pattern_1365015', 'pattern_1235299', 'pattern_921987', 'pattern_922057', 'pattern_742414', 'pattern_7373215', 'pattern_1124482', 'pattern_733855', 'pattern_1175350', 'pattern_855548']
#   > RESULT: MISS. Correct ID 'pattern_711607' not found.
#
# =============================================
# Testing Image 35/50: 7292988.jpeg
# =============================================
#   > Ground Truth ID: pattern_7292988
#   -> Keypoint crop: 4 keypoints, size=414x561
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/7292988.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 14.8739 ms
#   > Recommendations: ['pattern_620309', 'pattern_1327281', 'pattern_732717', 'pattern_560150', 'pattern_773337', 'pattern_576067', 'pattern_604493', 'pattern_960356', 'pattern_863020', 'pattern_706689']
#   > RESULT: MISS. Correct ID 'pattern_7292988' not found.
#
# =============================================
# Testing Image 36/50: 733855.jpeg
# =============================================
#   > Ground Truth ID: pattern_733855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 16.0991 ms
#   > Recommendations: ['pattern_172133', 'pattern_1274367', 'pattern_516362', 'pattern_7372262', 'pattern_1282948', 'pattern_1068017', 'pattern_624731', 'pattern_7352871', 'pattern_912900', 'pattern_858730']
#   > RESULT: MISS. Correct ID 'pattern_733855' not found.
#
# =============================================
# Testing Image 37/50: 7348838.jpg
# =============================================
#   > Ground Truth ID: pattern_7348838
#   -> Keypoint crop: 4 keypoints, size=367x605
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/7348838.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 18.6717 ms
#   > Recommendations: ['pattern_7327948', 'pattern_1048702', 'pattern_1302397', 'pattern_988974', 'pattern_7291766', 'pattern_7352871', 'pattern_1277075', 'pattern_1166369', 'pattern_7313250', 'pattern_1206227']
#   > RESULT: MISS. Correct ID 'pattern_7348838' not found.
#
# =============================================
# Testing Image 38/50: 7392773.jpeg
# =============================================
#   > Ground Truth ID: pattern_7392773
#   -> Keypoint crop: 4 keypoints, size=315x463
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/7392773.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 14.0555 ms
#   > Recommendations: ['pattern_1105725', 'pattern_773337', 'pattern_1036695', 'pattern_790309', 'pattern_7352871', 'pattern_77372', 'pattern_30588', 'pattern_43940', 'pattern_483156', 'pattern_1282948']
#   > RESULT: MISS. Correct ID 'pattern_7392773' not found.
#
# =============================================
# Testing Image 39/50: 76823.jpeg
# =============================================
#   > Ground Truth ID: pattern_76823
#   -> Keypoint crop: 4 keypoints, size=294x458
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/76823.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 15.7027 ms
#   > Recommendations: ['pattern_7444516', 'pattern_1060127', 'pattern_7394818', 'pattern_637934', 'pattern_1130785', 'pattern_7342182', 'pattern_1092437', 'pattern_429365', 'pattern_7364703', 'pattern_108023']
#   > RESULT: MISS. Correct ID 'pattern_76823' not found.
#
# =============================================
# Testing Image 40/50: 796740.jpeg
# =============================================
#   > Ground Truth ID: pattern_796740
#   -> Keypoint crop: 4 keypoints, size=290x416
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/796740.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > Query Time: 17.0975 ms
#   > Recommendations: ['pattern_960356', 'pattern_650108', 'pattern_557799', 'pattern_624731', 'pattern_863020', 'pattern_801593', 'pattern_1196039', 'pattern_1185945', 'pattern_516362', 'pattern_554684']
#   > RESULT: MISS. Correct ID 'pattern_796740' not found.
#
# =============================================
# Testing Image 41/50: 803939.jpeg
# =============================================
#   > Ground Truth ID: pattern_803939
#   -> Keypoint crop: 4 keypoints, size=283x403
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/803939.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > Query Time: 17.2331 ms
#   > Recommendations: ['pattern_1029757', 'pattern_7362158', 'pattern_1302768', 'pattern_1365015', 'pattern_7374998', 'pattern_1192496', 'pattern_1263859', 'pattern_7372262', 'pattern_1084426', 'pattern_7415405']
#   > RESULT: MISS. Correct ID 'pattern_803939' not found.
#
# =============================================
# Testing Image 42/50: 804035.jpg
# =============================================
#   > Ground Truth ID: pattern_804035
#   -> Keypoint crop: 4 keypoints, size=312x480
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/804035.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 17.1125 ms
#   > Recommendations: ['pattern_463263', 'pattern_7394818', 'pattern_1036695', 'pattern_486548', 'pattern_7425515', 'pattern_747802', 'pattern_429365', 'pattern_1079849', 'pattern_1003367', 'pattern_1282948']
#   > RESULT: MISS. Correct ID 'pattern_804035' not found.
#
# =============================================
# Testing Image 43/50: 813991.jpg
# =============================================
#   > Ground Truth ID: pattern_813991
#   -> Keypoint crop: 4 keypoints, size=371x597
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/813991.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > Query Time: 15.5617 ms
#   > Recommendations: ['pattern_524796', 'pattern_790309', 'pattern_693900', 'pattern_1036695', 'pattern_512075', 'pattern_7308711', 'pattern_773337', 'pattern_863020', 'pattern_7352871', 'pattern_509334']
#   > RESULT: MISS. Correct ID 'pattern_813991' not found.
#
# =============================================
# Testing Image 44/50: 844144.jpg
# =============================================
#   > Ground Truth ID: pattern_844144
#   -> Keypoint crop: 4 keypoints, size=361x556
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/844144.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > Query Time: 15.2618 ms
#   > Recommendations: ['pattern_1233729', 'pattern_1165175', 'pattern_7324661', 'pattern_7377058', 'pattern_1325801', 'pattern_972398', 'pattern_1147272', 'pattern_1019395', 'pattern_1247231', 'pattern_247632']
#   > RESULT: MISS. Correct ID 'pattern_844144' not found.
#
# =============================================
# Testing Image 45/50: 9042.jpeg
# =============================================
#   > Ground Truth ID: pattern_9042
#   -> Crop too small (640x5). Falling back to segmentation.
#   -> Pose failed. Fallback crop (Segment) for Evaluation_Sweaters/cardigans/9042.jpeg
#   -> Segmentation crop: size=640x545
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 15.6263 ms
#   > Recommendations: ['pattern_524796', 'pattern_773337', 'pattern_863020', 'pattern_77372', 'pattern_581854', 'pattern_557799', 'pattern_863020', 'pattern_1105725', 'pattern_733765', 'pattern_1357733']
#   > RESULT: MISS. Correct ID 'pattern_9042' not found.
#
# =============================================
# Testing Image 46/50: 914227.jpeg
# =============================================
#   > Ground Truth ID: pattern_914227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 14.1544 ms
#   > Recommendations: ['pattern_805933', 'pattern_914227', 'pattern_1059900', 'pattern_7352871', 'pattern_790309', 'pattern_1068017', 'pattern_1105725', 'pattern_1344089', 'pattern_512075', 'pattern_912900']
#   > RESULT: HIT! Correct ID 'pattern_914227' was found.
#
# =============================================
# Testing Image 47/50: 922057.jpg
# =============================================
#   > Ground Truth ID: pattern_922057
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 13.8415 ms
#   > Recommendations: ['pattern_978889', 'pattern_1196039', 'pattern_808678', 'pattern_1244593', 'pattern_1144145', 'pattern_7415052', 'pattern_516362', 'pattern_1237000', 'pattern_1292756', 'pattern_1311076']
#   > RESULT: MISS. Correct ID 'pattern_922057' not found.
#
# =============================================
# Testing Image 48/50: 933944.jpeg
# =============================================
#   > Ground Truth ID: pattern_933944
#   -> Keypoint crop: 4 keypoints, size=253x420
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/933944.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 19.1805 ms
#   > Recommendations: ['pattern_997785', 'pattern_1027180', 'pattern_2037', 'pattern_937640', 'pattern_949139', 'pattern_1116415', 'pattern_624175', 'pattern_1196039', 'pattern_242355', 'pattern_7433264']
#   > RESULT: MISS. Correct ID 'pattern_933944' not found.
#
# =============================================
# Testing Image 49/50: 949096.jpeg
# =============================================
#   > Ground Truth ID: pattern_949096
#   -> Keypoint crop: 4 keypoints, size=141x213
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/949096.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 16.6925 ms
#   > Recommendations: ['pattern_949096', 'pattern_1278116', 'pattern_1075778', 'pattern_579029', 'pattern_1129874', 'pattern_7293487', 'pattern_862027', 'pattern_1129874', 'pattern_309159', 'pattern_847087']
#   > RESULT: HIT! Correct ID 'pattern_949096' was found.
#
# =============================================
# Testing Image 50/50: 997785.jpeg
# =============================================
#   > Ground Truth ID: pattern_997785
#   -> Keypoint crop: 4 keypoints, size=288x456
#   -> Smart crop (Pose) for Evaluation_Sweaters/cardigans/997785.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > Query Time: 18.6494 ms
#   > Recommendations: ['pattern_1225181', 'pattern_7432813', 'pattern_1367796', 'pattern_1365015', 'pattern_997785', 'pattern_7345845', 'pattern_1192496', 'pattern_875160', 'pattern_1326248', 'pattern_1098541']
#   > RESULT: HIT! Correct ID 'pattern_997785' was found.
#
# --- Batch recommendation complete. ---
#
# ================== FINAL RESULTS ==================
# Total Images Processed: 50
# Total Hits (Recall@10): 4
# Average Accuracy (R@10): 8.00%
# Average Query Time: 16.4388 ms
# =================================================
